# %%
import pandas as pd
import joblib
import numpy as np
from sklearn.impute import SimpleImputer

nb15_dataset = pd.read_csv("C:/Users/katsa/OneDrive/Jupyter_files/shallow_models_cic_nb15/nb_12_feat_test_dataset.csv")

# %%
nb15_dataset = nb15_dataset.sample(frac=0.1)
nb15_dataset.reset_index(drop=True, inplace=True)
nb15_dataset.head()
# Out:
#     dsport      dur  Spkts  Dpkts  sbytes  dbytes  smeansz  dmeansz  \
# 0     53.0    1.148      2      2     146     178       73       89
# 1     80.0  668.762     10      8     810     354       81       44
# 2  37436.0   20.494     56     58    3390   41676       61      719
# 3  33741.0   27.939     64     66    3806   52378       59      794
# 4  13439.0  104.090      4      4     544     304      136       76
#
#    flow_bytes/s  flow_packets/s  fwd_packets/s  bwd_packets/s   Label
# 0  2.822300e+08    3.484321e+06   1.742160e+06   1.742160e+06  BENIGN
# 1  1.740530e+06    2.691540e+04   1.495300e+04   1.196240e+04  ATTACK
# 2  2.198985e+09    5.562604e+06   2.732507e+06   2.830097e+06  BENIGN
# 3  2.010952e+09    4.652994e+06   2.290705e+06   2.362289e+06  BENIGN
# 4  8.146796e+06    7.685657e+04   3.842828e+04   3.842828e+04  BENIGN

# %%
# Define the discriminator model
import torch
from torch import nn

class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(data_dim, 8),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(8, 4),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(4, 1),
            nn.Sigmoid()
        )

    def forward(self, data):
        validity = self.model(data)
        return validity

# %%
# save all the different network configurations
import glob

discr_models_lst = glob.glob('./models/discr_model*.pth')
print(discr_models_lst)
# Out:
# ['./models\\discr_model-lr=0.0002-batch=64-epochs=0.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=1.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=10.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=11.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=12.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=13.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=14.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=15.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=16.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=17.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=18.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=19.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=2.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=20.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=21.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=22.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=23.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=24.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=25.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=26.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=27.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=28.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=29.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=3.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=30.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=31.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=32.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=33.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=34.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=35.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=36.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=37.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=38.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=39.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=4.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=40.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=41.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=42.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=43.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=44.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=45.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=46.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=47.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=48.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=49.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=5.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=50.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=51.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=52.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=53.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=54.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=55.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=56.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=57.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=58.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=59.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=6.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=60.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=61.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=62.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=63.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=64.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=65.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=66.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=67.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=68.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=69.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=7.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=70.pth', './mo ...

# %%
discr_models_lst[0][9:-3]
# Out:
# 'discr_model-lr=0.0002-batch=64-epochs=0.'

# %%
data_dim = 12
discriminator = Discriminator()

# %%
selected_features_nb15 = ['dsport', 'dur', 'Spkts', 'Dpkts', 'sbytes', 'dbytes', 'smeansz', 
                          'dmeansz', 'flow_bytes/s', 'flow_packets/s', 'fwd_packets/s', 'bwd_packets/s']

# %%
print(nb15_dataset.columns)
# Out:
# Index(['dsport', 'dur', 'Spkts', 'Dpkts', 'sbytes', 'dbytes', 'smeansz',
#        'dmeansz', 'flow_bytes/s', 'flow_packets/s', 'fwd_packets/s',
#        'bwd_packets/s', 'Label'],
#       dtype='object')

# %%
minmaxscaler = joblib.load('minmaxscaler')

# %%
simp = SimpleImputer(keep_empty_features=True)

nb15_dataset_labels = nb15_dataset['Label']

nb15_dataset = nb15_dataset[selected_features_nb15]

nb15_dataset.replace([np.inf, -np.inf], np.nan, inplace=True)

nb15_dataset_features = simp.fit_transform(nb15_dataset)

nb15_dataset_features = minmaxscaler.transform(nb15_dataset_features)

# %%
num_samples = len(nb15_dataset_features)
best_accuracy_normal = 0
best_accuracy_attack = 0
total_benign_conn = nb15_dataset_labels.value_counts().BENIGN
total_attack_conn = nb15_dataset_labels.value_counts().ATTACK

for PATH_discr in discr_models_lst:
    discriminator.load_state_dict(torch.load(PATH_discr))
    discriminator.eval()
    correct_prediction_normal = 0
    correct_prediction_attack = 0
    for i in range(len(nb15_dataset_features)):
        row_label = nb15_dataset_labels[i]
        row_features = nb15_dataset_features[i]
        row_features = torch.tensor(row_features).float()
        model_output = discriminator(row_features)
        if model_output < 0.5:
            attack = True
        else:
            attack = False
        if (row_label == 'BENIGN' and attack == False):
            correct_prediction_normal += 1
        if (row_label == 'ATTACK' and attack == True):
            correct_prediction_attack += 1
    current_accuracy_normal = correct_prediction_normal / total_benign_conn
    current_accuracy_attack = correct_prediction_attack / total_attack_conn
    output = (f'Number of total samples: {num_samples} | '
              f'Number of correct BENIGN predictions: {correct_prediction_normal} | '
              f'Number of total BENIGN connections: {total_benign_conn} | '
              f'Number of correct ATTACK predictions: {correct_prediction_attack} | '
              f'Number of total ATTACK connections: {total_attack_conn} | '
              f'Accuracy BENIGN: {current_accuracy_normal} | '
              f'Accuracy ATTACK: {current_accuracy_attack} ')
    if current_accuracy_normal > best_accuracy_normal:
        best_pair_normal  = {PATH_discr : current_accuracy_normal}
        best_accuracy_normal = current_accuracy_normal
    if current_accuracy_attack > best_accuracy_attack:
        best_pair_attack = {PATH_discr : current_accuracy_attack}
        best_accuracy_attack = current_accuracy_attack
    print('Results of ' + str(PATH_discr) + ' ...')
    print(output)
    file_name = './test_eval/' + 'output-' + PATH_discr[9:-3] + 'txt'
    file = open(file_name, 'w')
    a = file.write(output)
    file.close()

print('The best pair for BENIGN is ' + str(best_pair_normal))
print('The best piar for ATTACK is ' + str(best_pair_attack))
# Out:
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=0.pth ...
# Number of total samples: 10160 | Number of correct BENIGN predictions: 8586 | Number of total BENIGN connections: 8842 | Number of correct ATTACK predictions: 227 | Number of total ATTACK connections: 1318 | Accuracy BENIGN: 0.971047274372314 | Accuracy ATTACK: 0.17223065250379363
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=1.pth ...
# Number of total samples: 10160 | Number of correct BENIGN predictions: 8065 | Number of total BENIGN connections: 8842 | Number of correct ATTACK predictions: 940 | Number of total ATTACK connections: 1318 | Accuracy BENIGN: 0.9121239538565935 | Accuracy ATTACK: 0.7132018209408194
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=10.pth ...
# Number of total samples: 10160 | Number of correct BENIGN predictions: 8821 | Number of total BENIGN connections: 8842 | Number of correct ATTACK predictions: 901 | Number of total ATTACK connections: 1318 | Accuracy BENIGN: 0.9976249717258538 | Accuracy ATTACK: 0.6836115326251897
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=11.pth ...
# Number of total samples: 10160 | Number of correct BENIGN predictions: 8826 | Number of total BENIGN connections: 8842 | Number of correct ATTACK predictions: 903 | Number of total ATTACK connections: 1318 | Accuracy BENIGN: 0.9981904546482696 | Accuracy ATTACK: 0.6851289833080425
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=12.pth ...
# Number of total samples: 10160 | Number of correct BENIGN predictions: 8829 | Number of total BENIGN connections: 8842 | Number of correct ATTACK predictions: 882 | Number of total ATTACK connections: 1318 | Accuracy BENIGN: 0.998529744401719 | Accuracy ATTACK: 0.669195751138088
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=13.pth ...
# Number of total samples: 10160 | Number of correct BENIGN predictions: 8828 | Number of total BENIGN connections: 8842 | Number of correct ATTACK predictions: 889 | Number of total ATTACK connections: 1318 | Accuracy BENIGN: 0.9984166478172359 | Accuracy ATTACK: 0.6745068285280729
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=14.pth ...
# Number of total samples: 10160 | Number of correct BENIGN predictions: 8827 | Number of total BENIGN connections: 8842 | Number of correct ATTACK predictions: 943 | Number of total ATTACK connections: 1318 | Accuracy BENIGN: 0.9983035512327527 | Accuracy ATTACK: 0.7154779969650986
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=15.pth ...
# Number of total samples: 10160 | Number of correct BENIGN predictions: 8828 | Number of total BENIGN connections: 8842 | Number of correct ATTACK predictions: 970 | Number of total ATTACK connections: 1318 | Accuracy BENIGN: 0.9984166478172359 | Accuracy ATTACK: 0.7359635811836115
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=16.pth ...
# Number of total samples: 10160 | Number of correct BENIGN predictions: 8826 | Number of total BENIGN connections: 8842 | Number of correct ATTACK predictions: 989 | Number of total ATTACK connections: 1318 | Accuracy BENIGN: 0.9981904546482696 | Accuracy ATTACK: 0.7503793626707133
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=17.pth ...
# Number of total samples: 10160 | Number of correct BENIGN predictions: 8828 | Number of total BENIGN connections: 8842 | Number of correct ATTACK predictions: 934 | Number of total ATTACK connections: 1318 | Accuracy BENIGN: 0.9984166478172359 | Accuracy ATTACK: 0.708649468892261
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=18.pth ...
# Number of total samples: 10160 | Number of correct BENIGN predictions: 8828 | Number of total BENIGN connections: 8842 | Number of correct ATTACK predictions: 911 | Number of total ATTACK connections: 1318 | Accuracy BENIGN: 0.9984166478172359 | Accuracy ATTACK: 0.6911987860394537
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=19.pth ...
# Number of total samples: 10160 | Number of correct BENIGN predictions: 8827 | Number of total BENIGN connections: 8842 | Number of correct ATTACK predictions: 938 | Number of total ATTACK connections: 1318 | Accuracy BENIGN: 0.9983035512327527 | Accuracy ATTACK: 0.7116843702579666
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=2.pth ...
# Number of total samples: 10160 | Number of correct BENIGN predictions: 8043 | Number of total BENIGN connections: 8842 | Number of correct ATTACK predictions: 1017 | Number of total ATTACK connections: 1318 | Accuracy BENIGN: 0.9096358289979642 | Accuracy ATTACK: 0.7716236722306525
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=20.pth ...
# Number of total samples: 10160 | Number of correct BENIGN predictions: 8831 | Number of total BENIGN connections: 8842 | Number of correct ATTACK predictions: 881 | Number of total ATTACK connections: 1318 | Accuracy BENIGN: 0.9987559375706854 | Accuracy ATTACK: 0.6684370257966616
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=21.pth ...
# Number of total samples: 10160 | Number of correct BENIGN predictions: 8827 | Number of total BENIGN connections: 8842 | Number of correct ATTACK predictions: 976 | Number of total ATTACK connections: 1318 | Accuracy BENIGN: 0.9983035512327527 | Accuracy ATTACK: 0.7405159332321699
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=22.pth ...
# Number of total samples: 10160 | Number of correct BENIGN predictions: 8823 | Number of total BENIGN connections: 8842 | Number of correct ATTACK predictions: 881 | Number of total ATTACK connections: 1318 | Accuracy BENIGN: 0.9978511648948202 | Accuracy ATTACK: 0.6684370257966616
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=23.pth ...
# Number of total samples: 10160 | Number of correct BENIGN predictions: 8829 | Number of total BENIGN connections: 8842 | Number of correct ATTACK predictions: 915 | Number of total ATTACK connections: 1318 | Accuracy BENIGN: 0.998529744401719 | Accuracy ATTACK: 0.6942336874051593
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=24.pth ...
# Number of total samples: 10160 | Number of correct BENIGN predictions: 8827 | Number of total BENIGN connections: 8842 | Number of correct ATTACK predictions: 922 | Number of total ATTACK connections: 1318 | Accuracy BENIGN: 0.9983035512327527 | Accuracy ATTACK: 0.6995447647951442
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=25.pth ...
# Number of total samples: 10160 | Number of correct BENIGN predictions: 8829 | Number of total BENIGN connections: 8842 | Number of correct ATTACK predictions: 943 | Number of total ATTACK connections: 1318 | Accuracy BENIGN: 0.998529744401719 | Accuracy ATTACK: 0.7154779969650986
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=26.pth ...
# Number of total samples: 10160 | Number of correct BENIGN predictions: 8829 | Number of total BENIGN connections: 8842 | Number of correct ATTACK predictions: 960 | Number of total ATTACK connections: 1318 | Accuracy BENIGN: 0.998529744401719 | Accuracy ATTACK: 0.7283763277693475
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=27.pth ...
# Number of total samples: 10160 | Number of correct BENIGN predictions: 8826 | Number of total BENIGN connections: 8842 | Number of correct ATTACK predictions: 941 | Number of total ATTACK connections: 1318 | Accuracy BENIGN: 0.9981904546482696 | Accuracy ATTACK: 0.7139605462822458
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=28.pth ...
# Number of total samples: 10160 | Number of correct BENIGN predictions: 8822 | Number of total BENIGN connections: 8842 | Number of correct ATTACK predictions: 953 | Number of total ATTACK connections: 1318 | Accuracy BENIGN: 0.