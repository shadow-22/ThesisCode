# %%
import pandas as pd
import joblib
import numpy as np
from sklearn.impute import SimpleImputer
from tabulate import tabulate

merged_dataset = pd.read_csv('C:/Users/katsa/OneDrive/Jupyter_files/cic_nb15_hybrid/merged_test_dataset.csv')

# %%
merged_dataset = merged_dataset.sample(frac=0.1)
merged_dataset.reset_index(drop=True, inplace=True)
merged_dataset.head()
# Out:
#    Destination Port  Flow Duration  Total Fwd Packets  Total Backward Packets  \
# 0              53.0          1.071                  2                       2
# 1               0.0          0.009                  2                       0
# 2           41336.0         46.248                  6                       8
# 3              53.0          0.003                  2                       0
# 4              53.0          0.925                  2                       2
#
#    Total Length of Fwd Packets  Total Length of Bwd Packets  \
# 0                          146                          178
# 1                          200                            0
# 2                          320                         1936
# 3                          264                            0
# 4                          146                          178
#
#    Fwd Packet Length Mean  Bwd Packet Length Mean  Flow Bytes/s  \
# 0                    73.0                    89.0  3.025210e+08
# 1                   100.0                     0.0  2.222222e+10
# 2                    53.0                   242.0  4.878049e+07
# 3                   132.0                     0.0  8.800000e+10
# 4                    73.0                    89.0  3.502703e+08
#
#    Flow Packets/s  Fwd Packets/s  Bwd Packets/s   Label
# 0    3.734827e+06   1.867414e+06   1.867414e+06  BENIGN
# 1    2.222222e+08   2.222222e+08   0.000000e+00  ATTACK
# 2    3.027158e+05   1.297353e+05   1.729805e+05  BENIGN
# 3    6.666667e+08   6.666667e+08   0.000000e+00  BENIGN
# 4    4.324324e+06   2.162162e+06   2.162162e+06  BENIGN

# %%
# Define the discriminator model
import torch
from torch import nn

class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(data_dim, 8),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(8, 4),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(4, 1),
            nn.Sigmoid()
        )

    def forward(self, data):
        validity = self.model(data)
        return validity

# %%
# save all the different network configurations
import glob

discr_models_lst = glob.glob('./models/discr_model*.pth')
print(discr_models_lst)
# Out:
# ['./models\\discr_model-lr=0.0002-batch=64-epochs=0.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=1.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=10.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=11.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=12.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=13.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=14.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=15.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=16.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=17.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=18.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=19.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=2.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=20.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=21.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=22.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=23.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=24.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=25.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=26.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=27.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=28.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=29.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=3.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=30.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=31.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=32.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=33.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=34.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=35.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=36.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=37.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=38.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=39.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=4.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=40.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=41.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=42.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=43.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=44.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=45.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=46.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=47.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=48.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=49.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=5.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=50.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=51.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=52.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=53.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=54.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=55.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=56.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=57.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=58.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=59.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=6.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=60.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=61.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=62.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=63.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=64.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=65.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=66.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=67.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=68.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=69.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=7.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=70.pth', './mo ...

# %%
discr_models_lst[0][9:-3]
# Out:
# 'discr_model-lr=0.0002-batch=64-epochs=0.'

# %%
data_dim = 12
discriminator = Discriminator()

# %%
# selected_features_nb15 = ['dsport', 'dur', 'Spkts', 'Dpkts', 'sbytes', 'dbytes', 'smeansz', 
#                           'dmeansz', 'flow_bytes/s', 'flow_packets/s', 'fwd_packets/s', 'bwd_packets/s']

# %%
print(merged_dataset.columns)
# Out:
# Index(['Destination Port', 'Flow Duration', 'Total Fwd Packets',
#        'Total Backward Packets', 'Total Length of Fwd Packets',
#        'Total Length of Bwd Packets', 'Fwd Packet Length Mean',
#        'Bwd Packet Length Mean', 'Flow Bytes/s', 'Flow Packets/s',
#        'Fwd Packets/s', 'Bwd Packets/s', 'Label'],
#       dtype='object')

# %%
minmaxscaler = joblib.load('minmaxscaler')

# %%
simp = SimpleImputer(keep_empty_features=True)

merged_dataset_labels = merged_dataset['Label']

# merged_dataset = merged_dataset[selected_features_nb15]
merged_dataset = merged_dataset.iloc[:, :-1]

merged_dataset.replace([np.inf, -np.inf], np.nan, inplace=True)

merged_dataset_features = simp.fit_transform(merged_dataset)

merged_dataset_features = minmaxscaler.transform(merged_dataset_features)

# %%
num_samples = len(merged_dataset_features)
total_benign_conn = merged_dataset_labels.value_counts().BENIGN
total_attack_conn = merged_dataset_labels.value_counts().ATTACK
best_accuracy = -1
best_pair = {}

for PATH_discr in discr_models_lst:
    discriminator.load_state_dict(torch.load(PATH_discr))
    discriminator.eval()
    true_positive = 0
    true_negative = 0
    false_positive = 0
    false_negative = 0
    for i in range(len(merged_dataset_features)):
        row_label = merged_dataset_labels[i]
        row_features = merged_dataset_features[i]
        row_features = torch.tensor(row_features).float()
        model_output = discriminator(row_features)
        if model_output < 0.5:
            attack = True
        else:
            attack = False
        if (row_label == 'BENIGN' and attack == False):
            true_negative += 1
        if (row_label == 'ATTACK' and attack == True):
            true_positive += 1
        if (row_label == 'BENIGN' and attack == True):
            false_positive += 1
        if (row_label == 'ATTACK' and attack == False):
            false_negative += 1
    
    benign_recall = true_negative / (true_negative + false_positive)
    attack_recall = true_positive / (true_positive + false_negative)
    
    benign_precision = true_negative / (true_negative + false_negative)
    attack_precision = true_positive / (true_positive + false_positive)
    
    benign_f1 = 2 * (benign_recall * benign_precision) / (benign_recall + benign_precision)
    attack_f1 = 2 * (attack_recall * attack_precision) / (attack_recall + attack_precision)
    
    accuracy = (true_positive + true_negative) / (true_positive + true_negative + false_positive + false_negative)
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_pair  = {PATH_discr : accuracy}
    
    data = {
        "BENIGN": {"Precision": benign_precision, "Recall": benign_recall, "F1-Score": benign_f1},
        "ATTACK": {"Precision": attack_precision, "Recall": attack_recall, "F1-Score": attack_f1}
    }
    
    # Convert the dictionary to a list of lists
    table = [[row_name] + list(row_data.values()) for row_name, row_data in data.items()]
    # Get the column names
    #column_names = [""] + list(data.values()[0].keys())
    column_names = ["Precision", "Recall", "F1-Score"]
    # Print the table using tabulate
    #print(tabulate(table, headers=column_names, tablefmt="fancy_grid"))
    
    str1 = 'Results of ' + str(PATH_discr) + ' ...'
    str2 = "Overall Accuracy: " + str(accuracy)
    str3 = tabulate(table, headers=column_names, tablefmt="fancy_grid")
    output = str1 + "\n" + str2 + "\n" + str3 + "\n" + "###################################################"
    print(output)
    
    output2 = str2 + "\n" + str(data)
    file_name = './test_eval2/' + 'output-' + PATH_discr[9:-3] + 'txt'
    file = open(file_name, 'w')
    a = file.write(output2)
    file.close()

print("Best model overall is: " + str(best_pair))
# Out:
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=0.pth ...
# Overall Accuracy: 0.8354693453411847
# ╒════════╤═════════════╤═══════════╤════════════╕
# │        │   Precision │    Recall │   F1-Score │
# ╞════════╪═════════════╪═══════════╪════════════╡
# │ BENIGN │    0.841345 │ 0.990557  │  0.909875  │
# ├────────┼─────────────┼───────────┼────────────┤
# │ ATTACK │    0.384615 │ 0.0306279 │  0.0567376 │
# ╘════════╧═════════════╧═══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=1.pth ...
# Overall Accuracy: 0.844425750903063
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.87709  │ 0.947179 │   0.910788 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.531659 │ 0.311179 │   0.392581 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=10.pth ...
# Overall Accuracy: 0.8919788213172349
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.915686 │ 0.959514 │   0.937088 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.720456 │ 0.541501 │   0.61829  │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=11.pth ...
# Overall Accuracy: 0.8883170864466327
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.917221 │ 0.952786 │   0.934665 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.693252 │ 0.553752 │   0.615699 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=12.pth ...
# Overall Accuracy: 0.8952941758622396
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.915257 │ 0.964412 │   0.939192 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.743949 │ 0.5366   │   0.623488 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=13.pth ...
# Overall Accuracy: 0.9016279875303083
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.
│
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=79.pth ...
# Overall Accuracy: 0.9278539264684051
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.924181 │ 0.995633 │   0.958577 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.962148 │ 0.57611  │   0.72069  │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=8.pth ...
# Overall Accuracy: 0.8876243257954377
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.915219 │ 0.954379 │   0.934389 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.695669 │ 0.541194 │   0.608786 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=80.pth ...
# Overall Accuracy: 0.9270622000098966
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.923047 │ 0.996046 │   0.958158 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.965195 │ 0.569066 │   0.715992 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=81.pth ...
# Overall Accuracy: 0.9264684051660151
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.922812 │ 0.995574 │   0.957813 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.96112  │ 0.567841 │   0.713901 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=82.pth ...
# Overall Accuracy: 0.9276065119501212
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.923186 │ 0.996577 │   0.958479 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.96976  │ 0.569678 │   0.717731 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=83.pth ...
# Overall Accuracy: 0.924637537730714
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.919893 │ 0.996931 │   0.956864 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.971831 │ 0.549464 │   0.702015 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=84.pth ...
# Overall Accuracy: 0.924192191597803
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.919763 │ 0.996518 │   0.956603 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.968125 │ 0.548851 │   0.700547 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=85.pth ...
# Overall Accuracy: 0.9248354693453412
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.919819 │ 0.997285 │   0.956987 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.974973 │ 0.548851 │   0.702332 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=86.pth ...
# Overall Accuracy: 0.9181057944480182
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.919774 │ 0.988551 │   0.952923 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.902903 │ 0.552527 │   0.685541 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=87.pth ...
# Overall Accuracy: 0.9266663367806423
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.922598 │ 0.996105 │   0.957943 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.965535 │ 0.566309 │   0.7139   │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=88.pth ...
# Overall Accuracy: 0.9272601316245237
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.92694  │ 0.991383 │   0.958079 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.930043 │ 0.594487 │   0.725336 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=89.pth ...
# Overall Accuracy: 0.8818843089712505
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.878635 │ 0.996813 │   0.934001 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.945233 │ 0.285452 │   0.438485 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=9.pth ...
# Overall Accuracy: 0.8883170864466327
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.916889 │ 0.953199 │   0.934691 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.694295 │ 0.551608 │   0.614781 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=90.pth ...
# Overall Accuracy: 0.8835667276955812
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.880588 │ 0.996223 │   0.934843 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.938462 │ 0.298928 │   0.453426 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=91.pth ...
# Overall Accuracy: 0.9102380127665891
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.904632 │ 0.99817  │   0.949102 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.979511 │ 0.453905 │   0.620343 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=92.pth ...
# Overall Accuracy: 0.919540798654065
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.914672 │ 0.997049 │   0.954086 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.971248 │ 0.517305 │   0.67506  │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=93.pth ...
# Overall Accuracy: 0.9266168538769854
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.922917 │ 0.995633 │   0.957897 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.961658 │ 0.568453 │   0.714533 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=94.pth ...
# Overall Accuracy: 0.9258746103221337
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.922576 │ 0.995102 │   0.957467 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.957062 │ 0.566616 │   0.711812 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=95.pth ...
# Overall Accuracy: 0.919986144786976
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.915659 │ 0.996341 │   0.954298 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.965011 │ 0.523737 │   0.678976 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=96.pth ...
# Overall Accuracy: 0.9258251274184769
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.921695 │ 0.996164 │   0.957484 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.965717 │ 0.560796 │   0.709552 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=97.pth ...
# Overall Accuracy: 0.9259240932257905
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.922951 │ 0.994688 │   0.957478 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.953799 │ 0.569066 │   0.712833 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=98.pth ...
# Overall Accuracy: 0.926270473551388
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.922841 │ 0.995279 │   0.957692 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.958656 │ 0.568147 │   0.713462 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=99.pth ...
# Overall Accuracy: 0.9261220248404176
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.922551 │ 0.995456 │   0.957618 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.960021 │ 0.566309 │   0.712387 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Best model overall is: {'./models\\discr_model-lr=0.0002-batch=64-epochs=79.pth': 0.9278539264684051}
