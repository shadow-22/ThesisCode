# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn import metrics
from sklearn.pipeline import make_pipeline

# %%
pipe = make_pipeline(
    SimpleImputer(), StandardScaler(), SVC(kernel='rbf', gamma=0.001, C=1)
)

# %%
nb_train_dataset_path = 'C:/Users/katsa/OneDrive/Jupyter_files/shallow_models_cic_nb15/nb_all_feat_train_dataset.csv'
nb_train_dataset = pd.read_csv(nb_train_dataset_path)
print(len(nb_train_dataset))
nb_train_dataset = nb_train_dataset.sample(frac=1/6)
print(len(nb_train_dataset))
nb_train_dataset.head()
# Out:
# 406407
# 67734
#           sport   dsport       dur  sbytes  dbytes  sttl  dttl  sloss  dloss  \
# 362961  45307.0     53.0  0.000983     146     178    31    29      0      0
# 226749   8188.0  42295.0  0.225069    8928     320    31    29      4      1
# 37975   46519.0     25.0  0.996590   37262    3380    31    29     18      8
# 158378  43320.0   6881.0  0.038976    1540    1644    31    29      4      4
# 344485   1043.0     53.0  0.000009     114       0   254     0      0      0
#
#                Sload  ...  service_ftp-data  service_http  service_irc  \
# 362961  5.940997e+05  ...                 0             0            0
# 226749  2.947008e+05  ...                 1             0            0
# 37975   2.933684e+05  ...                 0             0            0
# 158378  2.963875e+05  ...                 0             0            0
# 344485  5.066666e+07  ...                 0             0            0
#
#         service_pop3  service_radius  service_smtp  service_snmp  service_ssh  \
# 362961             0               0             0             0            0
# 226749             0               0             0             0            0
# 37975              0               0             1             0            0
# 158378             0               0             0             0            0
# 344485             0               0             0             0            0
#
#         service_ssl   Label
# 362961            0  BENIGN
# 226749            0  BENIGN
# 37975             0  BENIGN
# 158378            0  BENIGN
# 344485            0  ATTACK
#
# [5 rows x 203 columns]

# %%
nb_test_dataset_path = 'C:/Users/katsa/OneDrive/Jupyter_files/shallow_models_cic_nb15/nb_all_feat_test_dataset.csv'
nb_test_dataset = pd.read_csv(nb_test_dataset_path)
print(len(nb_test_dataset))
#nb_test_dataset = nb_test_dataset.sample(frac=1/6)
print(len(nb_test_dataset))
nb_test_dataset.head()
# Out:
# 101602
# 16934
#          sport  dsport       dur  sbytes  dbytes  sttl  dttl  sloss  dloss  \
# 40571   1043.0    53.0  0.000009     264       0    60     0      0      0
# 50274   3753.0    53.0  0.000971     146     178    31    29      0      0
# 32317  53721.0   111.0  0.004658     568     312    31    29      0      0
# 46661  35793.0  5190.0  1.364151    3848   19084    31    29     11     15
# 23971   6697.0  5504.0  0.006074    3736    2456    31    29      7      7
#
#               Sload  ...  service_ftp-data  service_http  service_irc  \
# 40571  1.173333e+08  ...                 0             0            0
# 50274  6.014418e+05  ...                 0             0            0
# 32317  7.316445e+05  ...                 0             0            0
# 46661  2.212072e+04  ...                 0             0            0
# 23971  4.648008e+06  ...                 0             0            0
#
#        service_pop3  service_radius  service_smtp  service_snmp  service_ssh  \
# 40571             0               0             0             0            0
# 50274             0               0             0             0            0
# 32317             0               0             0             0            0
# 46661             0               0             0             0            0
# 23971             0               0             0             0            0
#
#        service_ssl   Label
# 40571            0  BENIGN
# 50274            0  BENIGN
# 32317            0  BENIGN
# 46661            0  BENIGN
# 23971            0  BENIGN
#
# [5 rows x 203 columns]

# %%
X_train = nb_train_dataset.drop('Label', axis=1)
y_train = nb_train_dataset['Label']

X_test = nb_test_dataset.drop('Label', axis=1)
y_test = nb_test_dataset['Label']

# %%
pipe.fit(X_train.to_numpy(), y_train.to_numpy())
predictions = pipe.predict(X_test.to_numpy())
print(metrics.accuracy_score(y_test.to_numpy(), predictions))
print(metrics.classification_report(y_test.to_numpy(), predictions))
# Out:
# 0.9870674382898311
#               precision    recall  f1-score   support
#
#       ATTACK       0.91      1.00      0.95      2203
#       BENIGN       1.00      0.99      0.99     14731
#
#     accuracy                           0.99     16934
#    macro avg       0.96      0.99      0.97     16934
# weighted avg       0.99      0.99      0.99     16934

# %%
import joblib
joblib.dump(pipe, "SVMmodel")
joblib.dump(pipe[1], "scaler")
# Out:
# ['scaler']
