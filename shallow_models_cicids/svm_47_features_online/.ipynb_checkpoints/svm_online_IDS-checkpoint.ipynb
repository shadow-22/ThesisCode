# %%
from nfstream import NFStreamer, NFPlugin
import pandas as pd
from sklearn.impute import SimpleImputer
import numpy as np

# %%
import joblib
model = joblib.load('SVMModel')
sscaler = joblib.load('scaler')

# %%
from ModelPredictionLive import ModelPrediction

# %%
# the max_nflows is only implemented in latest version of nfstream!
ml_streamer = NFStreamer(source="Realtek 8822CE Wireless LAN 802.11ac PCI-E NIC",
                        udps=ModelPrediction(my_model=model, my_scaler=sscaler),
                        active_timeout=5, idle_timeout=5,
                        statistical_analysis=True)

# %%
with open('C:/Users/katsa/OneDrive/Jupyter_files/make_http_requests/urls.txt', 'r') as f:
    url_list = [line.strip() for line in f.readlines()]

# %%
flows_predictions = []
n_normal = 0
n_attacks = 0
for flow in ml_streamer:
    if flow.requested_server_name in url_list:
        prediction = flow.udps.model_prediction
        flows_predictions.append(prediction)
        if prediction == 'BENIGN':
            n_normal += 1
        elif prediction == 'ATTACK':
            n_attacks += 1
        print("Server name: " + str(flow.requested_server_name))
        print("Prediction:" + str(prediction))
        print("Number of normal connections so far: " + str(n_normal))
        print("Number of attack connections so far: " + str(n_attacks))
        print("")
# Out:
# Server name: google.com
# Prediction:['ATTACK']
# Number of normal connections so far: 0
# Number of attack connections so far: 1
#
# Server name: youtube.com
# Prediction:['ATTACK']
# Number of normal connections so far: 0
# Number of attack connections so far: 2
#
# Server name: facebook.com
# Prediction:['ATTACK']
# Number of normal connections so far: 0
# Number of attack connections so far: 3
#
# Server name: google.com
# Prediction:['BENIGN']
# Number of normal connections so far: 1
# Number of attack connections so far: 3
#
# Server name: twitter.com
# Prediction:['BENIGN']
# Number of normal connections so far: 2
# Number of attack connections so far: 3
#
# Server name: twitter.com
# Prediction:['ATTACK']
# Number of normal connections so far: 2
# Number of attack connections so far: 4
#
# Server name: instagram.com
# Prediction:['BENIGN']
# Number of normal connections so far: 3
# Number of attack connections so far: 4
#
# Server name: instagram.com
# Prediction:['ATTACK']
# Number of normal connections so far: 3
# Number of attack connections so far: 5
#
# Server name: google.com
# Prediction:['BENIGN']
# Number of normal connections so far: 4
# Number of attack connections so far: 5
#
# Server name: baidu.com
# Prediction:['BENIGN']
# Number of normal connections so far: 5
# Number of attack connections so far: 5
#
# Server name: baidu.com
# Prediction:['ATTACK']
# Number of normal connections so far: 5
# Number of attack connections so far: 6
#
# Server name: youtube.com
# Prediction:['ATTACK']
# Number of normal connections so far: 5
# Number of attack connections so far: 7
#
# Server name: facebook.com
# Prediction:['ATTACK']
# Number of normal connections so far: 5
# Number of attack connections so far: 8
#
# Server name: twitter.com
# Prediction:['ATTACK']
# Number of normal connections so far: 5
# Number of attack connections so far: 9
#
# Server name: instagram.com
# Prediction:['ATTACK']
# Number of normal connections so far: 5
# Number of attack connections so far: 10
#
# Server name: baidu.com
# Prediction:['BENIGN']
# Number of normal connections so far: 6
# Number of attack connections so far: 10
#
# Server name: baidu.com
# Prediction:['BENIGN']
# Number of normal connections so far: 7
# Number of attack connections so far: 10
#
# Server name: wikipedia.org
# Prediction:['BENIGN']
# Number of normal connections so far: 8
# Number of attack connections so far: 10
#
# Server name: wikipedia.org
# Prediction:['BENIGN']
# Number of normal connections so far: 9
# Number of attack connections so far: 10
#
# Server name: baidu.com
# Prediction:['BENIGN']
# Number of normal connections so far: 10
# Number of attack connections so far: 10
#
# Server name: wikipedia.org
# Prediction:['BENIGN']
# Number of normal connections so far: 11
# Number of attack connections so far: 10
#
# Server name: wikipedia.org
# Prediction:['ATTACK']
# Number of normal connections so far: 11
# Number of attack connections so far: 11
#
# Server name: yandex.ru
# Prediction:['ATTACK']
# Number of normal connections so far: 11
# Number of attack connections so far: 12
#
# Server name: dzen.ru
# Prediction:['BENIGN']
# Number of normal connections so far: 12
# Number of attack connections so far: 12
#
# Server name: dzen.ru
# Prediction:['BENIGN']
# Number of normal connections so far: 13
# Number of attack connections so far: 12
#
# Server name: whatsapp.com
# Prediction:['BENIGN']
# Number of normal connections so far: 14
# Number of attack connections so far: 12
#
# Server name: yahoo.com
# Prediction:['ATTACK']
# Number of normal connections so far: 14
# Number of attack connections so far: 13
#
# Server name: whatsapp.com
# Prediction:['BENIGN']
# Number of normal connections so far: 15
# Number of attack connections so far: 13
#
# Server name: yahoo.com
# Prediction:['ATTACK']
# Number of normal connections so far: 15
# Number of attack connections so far: 14
#
# Server name: whatsapp.com
# Prediction:['ATTACK']
# Number of normal connections so far: 15
# Number of attack connections so far: 15
#
# Server name: whatsapp.com
# Prediction:['ATTACK']
# Number of normal connections so far: 15
# Number of attack connections so far: 16
#
# Server name: xvideos.com
# Prediction:['BENIGN']
# Number of normal connections so far: 16
# Number of attack connections so far: 16
#
# Server name: xvideos.com
# Prediction:['ATTACK']
# Number of normal connections so far: 16
# Number of attack connections so far: 17
#
# Server name: pornhub.com
# Prediction:['BENIGN']
# Number of normal connections so far: 17
# Number of attack connections so far: 17
#
# Server name: pornhub.com
# Prediction:['BENIGN']
# Number of normal connections so far: 18
# Number of attack connections so far: 17
#
# Server name: pornhub.com
# Prediction:['ATTACK']
# Number of normal connections so far: 18
# Number of attack connections so far: 18
#
# Server name: xnxx.com
# Prediction:['ATTACK']
# Number of normal connections so far: 18
# Number of attack connections so far: 19
#
# Server name: live.com
# Prediction:['BENIGN']
# Number of normal connections so far: 19
# Number of attack connections so far: 19
#
# Server name: live.com
# Prediction:['ATTACK']
# Number of normal connections so far: 19
# Number of attack connections so far: 20
#
# Server name: xnxx.com
# Prediction:['BENIGN']
# Number of normal connections so far: 20
# Number of attack connections so far: 20
#
# Server name: xnxx.com
# Prediction:['BENIGN']
# Number of normal connections so far: 21
# Number of attack connections so far: 20
#
# Server name: tiktok.com
# Prediction:['BENIGN']
# Number of normal connections so far: 22
# Number of attack connections so far: 20
#
# Server name: tiktok.com
# Prediction:['ATTACK']
# Number of normal connections so far: 22
# Number of attack connections so far: 21
#
# Server name: linkedin.com
# Prediction:['BENIGN']
# Number of normal connections so far: 23
# Number of attack connections so far: 21
#
# Server name: linkedin.com
# Prediction:['BENIGN']
# Number of normal connections so far: 24
# Number of attack connections so far: 21
#
# Server name: reddit.com
# Prediction:['BENIGN']
# Number of normal connections so far: 25
# Number of attack connections so far: 21
#
# Server name: linkedin.com
# Prediction:['ATTACK']
# Number of normal connections so far: 25
# Number of attack connections so far: 22
#
# Server name: reddit.com
# Prediction:['ATTACK']
# Number of normal connections so far: 25
# Number of attack connections so far: 23
#
# Server name: openai.com
# Prediction:['ATTACK']
# Number of normal connections so far: 25
# Number of attack connections so far: 24
#
# Server name: linkedin.com
# Prediction:['BENIGN']
# Number of normal connections so far: 26
# Number of attack connections so far: 24
#
# Server name: openai.com
# Prediction:['BENIGN']
# Number of normal connections so far: 27
# Number of attack connections so far: 24
#
# Server name: openai.com
# Prediction:['BENIGN']
# Number of normal connections so far: 28
# Number of attack connections so far: 24
#
# Server name: openai.com
# Prediction:['ATTACK']
# Number of normal connections so far: 28
# Number of attack connections so far: 25
#
# Server name: office.com
# Prediction:['ATTACK']
# Number of normal connections so far: 28
# Number of attack connections so far: 26
#
# Server name: office.com
# Prediction:['BENIGN']
# Number of normal connections so far: 29
# Number of attack connections so far: 26
#
# Server name: netflix.com
# Prediction:['ATTACK']
# Number of normal connections so far: 29
# Number of attack connections so far: 27
#
# Server name: netflix.com
# Prediction:['ATTACK']
# Number of normal connections so far: 29
# Number of attack connections so far: 28
#
# Server name: dzen.ru
# Prediction:['BENIGN']
# Number of normal connections so far: 30
# Number of attack connections so far: 28
#
# Server name: bing.com
# Prediction:['ATTACK']
# Number of normal connections so far: 30
# Number of attack connections so far: 29
#
# Server name: office.com
# Prediction:['BENIGN']
# Number of normal connections so far: 31
# Number of attack connections so far: 29
#
# Server name: dzen.ru
# Prediction:['BENIGN']
# Number of normal connections so far: 32
# Number of attack connections so far: 29
#
# Server name: dzen.ru
# Prediction:['ATTACK']
# Number of normal connections so far: 32
# Number of attack connections so far: 30
#
# Server name: vk.com
# Prediction:['BENIGN']
# Number of normal connections so far: 33
# Number of attack connections so far: 30
#
# Server name: vk.com
# Prediction:['ATTACK']
# Number of normal connections so far: 33
# Number of attack connections so far: 31
#
# Server name: vk.com
# Prediction:['ATTACK']
# Number of normal connections so far: 33
# Number of attack connections so far: 32
#
# Server name: xhamster.com
# Prediction:['ATTACK']
# Number of normal connections so far: 33
# Number of attack connections so far: 33
#
# Server name: xhamster.com
# Prediction:['ATTACK']
# Number of normal connections so far: 33
# Number of attack connections so far: 34
#
# Server name: xhamster.com
# Prediction:['BENIGN']
# Number of normal connections so far: 34
# Number of attack connections so far: 34
#
# Server name: samsung.com
# Prediction:['BENIGN']
# Number of normal connections so far: 35
# Number of attack connections so far: 34
#
# Server name: xhamster.com
# Prediction:['BENIGN']
# Number of normal connections so far: 36
# Number of attack connections so far: 34
#
# Server name: samsung.com
# Prediction:['BENIGN']
# Number of normal connections so far: 37
# Number of attack connections so far: 34
#
# Server name: kathimerini.gr
# Prediction:['BENIGN']
# Number of normal connections so far: 38
# Number of attack connections so far: 34
#
# Server name: samsung.com
# Prediction:['ATTACK']
# Number of normal connections so far: 38
# Number of attack connections so far: 35
#
# Server name: kathimerini.gr
# Prediction:['ATTACK']
# Number of normal connections so far: 38
# Number of attack connections so far: 36
#
# Server name: kathimerini.gr
# Prediction:['ATTACK']
# Number of normal connections so far: 38
# Number of attack connections so far: 37
#
# Server name: capital.gr
# Prediction:['BENIGN']
# Number of normal connections so far: 39
# Number of attack connections so far: 37
#
# Server name: capital.gr
# Prediction:['BENIGN']
# Number of normal connections so far: 40
# Number of attack connections so far: 37
#
# Server name: capital.gr
# Prediction:['ATTACK']
# Number of normal connections so far: 40
# Number of attack connections so far: 38
#
# Server name: in.gr
# Prediction:['BENIGN']
# Number of normal connections so far: 41
# Number of attack connections so far: 38
#
# Server name: esos.gr
# Prediction:['BENIGN']
# Number of normal connections so far: 42
# Number of attack connections so far: 38
#
# Server name: in.gr
# Prediction:['ATTACK']
# Number of normal connections so far: 42
# Number of attack connections so far: 39
#
# Server name: shmmy.ntua.gr
# Prediction:['ATTACK']
# Number of normal connections so far: 42
# Number of attack connections so far: 40
#
# Server name: esos.gr
# Prediction:['ATTACK']
# Number of normal connections so far: 42
# Number of attack connections so far: 41
#
# Server name: shmmy.ntua.gr
# Prediction:['ATTACK']
# Number of normal connections so far: 42
# Number of attack connections so far: 42
#
# Server name: ntua.gr
# Prediction:['ATTACK']
# Number of normal connections so far: 42
# Number of attack connections so far: 43
#
# Server name: ntua.gr
# Prediction:['ATTACK']
# Number of normal connections so far: 42
# Number of attack connections so far: 44
#
# Server name: ntua.gr
# Prediction:['ATTACK']
# Number of normal connections so far: 42
# Number of attack connections so far: 45
#
# Server name: ece.ntua.gr
# Prediction:['BENIGN']
# Number of normal connections so far: 43
# Number of attack connections so far: 45
#
# Server name: ece.ntua.gr
# Prediction:['ATTACK']
# Number of normal connections so far: 43
# Number of attack connections so far: 46
#
# Server name: efsyn.gr
# Prediction:['BENIGN']
# Number of normal connections so far: 44
# Number of attack connections so far: 46
#
# Server name: efsyn.gr
# Prediction:['BENIGN']
# Number of normal connections so far: 45
# Number of attack connections so far: 46
#
# Server name: efsyn.gr
# Prediction:['ATTACK']
# Number of normal connections so far: 45
# Number of attack connections so far: 47
#
# Server name: ischool.gr
# Prediction:['ATTACK']
# Number of normal connections so far: 45
# Number of attack connections so far: 48
#
# Server name: efsyn.gr
# Prediction:['BENIGN']
# Number of normal connections so far: 46
# Number of attack connections so far: 48
#
# Server name: gov.gr
# Prediction:['BENIGN']
# Number of normal connections so far: 47
# Number of attack connections so far: 48
#
# Server name: gov.gr
# Prediction:['BENIGN']
# Number of normal connections so far: 48
# Number of attack connections so far: 48
#
# Server name: efsyn.gr
# Prediction:['BENIGN']
# Number of normal connections so far: 49
# Number of attack connections so far: 48
#
# Server name: efsyn.gr
# Prediction:['ATTACK']
# Number of normal connections so far: 49
# Number of attack connections so far: 49
#
# Server name: ischool.gr
# Prediction:['BENIGN']
# Number of normal connections so far: 50
# Number of attack connections so far: 49
#
# Server name: ischool.gr
# Prediction:['BENIGN']
# Number of normal connections so far: 51
# Number of attack connections so far: 49
#
# Server name: gov.gr
# Prediction:['ATTACK']
# Number of normal connections so far: 51
# Number of attack connections so far: 50
