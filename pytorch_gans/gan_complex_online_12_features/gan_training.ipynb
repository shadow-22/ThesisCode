# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets, transforms
from torchvision.utils import make_grid
from tqdm import tqdm
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer
import torch.optim as optim
from torch.autograd import Variable
from torch import FloatTensor, LongTensor
import joblib

# %%
# selected_features_nb15 = ['dsport', 'dur', 'Spkts', 'Dpkts', 'sbytes', 'dbytes', 'smeansz', 
#                           'dmeansz', 'flow_bytes/s', 'flow_packets/s', 'fwd_packets/s', 'bwd_packets/s']

# selected_features_total = selected_features_nb15

# %%
class PreProcessor:
    def __init__(self, file_path):
        self.input_dataset = pd.read_csv(file_path)
        #self.selected_features = selected_features
        
    def print_input_data(self):
        print('The input dataset has the following columns/features')
        print(self.input_dataset.columns)
        labels = self.input_dataset['Label']
        print('The labels are as follows')
        print(labels.value_counts())
        print(labels.value_counts().plot.pie())
        
    def preprocess(self):
        X, y = self.feature_selection()
        X = self.imputing(X)
        X = self.scaling(X)
        y = self.label_binarization(y)
        self.data = torch.tensor(X)
        self.targets = torch.tensor(y)
        
    def feature_selection(self):
        #X = self.input_dataset[self.selected_features]
        X = self.input_dataset.iloc[:, :-1]
        y = self.input_dataset['Label']
        return X, y
    
    def imputing(self, X):
        X.replace([np.inf, -np.inf], np.nan, inplace=True)
        Imp = SimpleImputer()
        X = Imp.fit_transform(X)
        return X
        
    def scaling(self, X):
        scaler = preprocessing.MinMaxScaler()
        X = scaler.fit_transform(X)
        joblib.dump(scaler, 'minmaxscaler')
        return X
    
    def label_binarization(self, y):
        for label in y:
            if (label != 'BENIGN' and label != 'ATTACK'):
                y.replace(label, 'ATTACK', inplace=True)
        y.replace('BENIGN', 1, inplace=True)
        y.replace('ATTACK', 0, inplace=True)
        return y
    
    def return_data(self):
        return self.data, self.targets

# %%
class MyDataset(Dataset):
    def __init__(self, file_path):
        preprocessor = PreProcessor(file_path)
        preprocessor.print_input_data()
        preprocessor.preprocess()
        self.data, self.targets = preprocessor.return_data()
        
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        row = self.data[idx]
        label = self.targets[idx]
        return row, label

# %%
num_epochs = 100

# %%
sample_path = 'C:/Users/katsa/OneDrive/Jupyter_files/cic_nb15_hybrid/merged_train_dataset.csv'
CICDataset = MyDataset(sample_path)
batch_size = 64
dataloader = DataLoader(CICDataset, batch_size=batch_size, 
                          shuffle=True, drop_last=True)
# Out:
# The input dataset has the following columns/features
# Index(['Destination Port', 'Flow Duration', 'Total Fwd Packets',
#        'Total Backward Packets', 'Total Length of Fwd Packets',
#        'Total Length of Bwd Packets', 'Fwd Packet Length Mean',
#        'Bwd Packet Length Mean', 'Flow Bytes/s', 'Flow Packets/s',
#        'Fwd Packets/s', 'Bwd Packets/s', 'Label'],
#       dtype='object')
# The labels are as follows
# BENIGN    234228
# ATTACK     45487
# Name: Label, dtype: int64
# Axes(0.22375,0.11;0.5775x0.77)

# %%
# Define the generator model

class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(latent_dim + 1, 8),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(8, 16),
            nn.BatchNorm1d(16, 0.8),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(16, 8),
            nn.BatchNorm1d(8, 0.8),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(8, data_dim),
            nn.Sigmoid()
        )

    def forward(self, z, label):
        label = torch.full((batch_size, 1), label)
        z = torch.cat((noise, label), 1)
        data = self.model(z)
        return data

# %%
# Define the discriminator model

class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(data_dim, 8),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(8, 4),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(4, 1),
            nn.Sigmoid()
        )

    def forward(self, data):
        validity = self.model(data)
        return validity

# %%
# Definition of hyperparameters

#data_dim=len(selected_features_total)
data_dim = 12
print(data_dim)
latent_dim = 4
lr = 0.0002
adversarial_loss = nn.BCELoss()
generator = Generator()
discriminator = Discriminator()
optimizer_G = optim.Adam(generator.parameters(), lr=lr, betas=(0.5, 0.999))
optimizer_D = optim.Adam(discriminator.parameters(), lr=lr, betas=(0.5, 0.999))
# Out:
# 12

# %%
noise = torch.randn(batch_size, latent_dim)

# %%
epochs_lst = [5, 10, 15, 20, 25, 30]

# %%
for epoch in range(num_epochs):
    for i, (data, labels) in enumerate(dataloader):
        batch_size = data.shape[0]
        real_data = Variable(data.type(FloatTensor))        
        labels = Variable(labels.float())
        labels = labels.view(-1, 1).type(FloatTensor)
        
        # Train the discriminator
        optimizer_D.zero_grad()
        d_real_outputs = discriminator(real_data)
        d_real_loss = adversarial_loss(d_real_outputs, labels)
        
        fake_data = generator(noise, 0)
        d_fake_outputs = discriminator(fake_data.detach())
        d_fake_loss1 = adversarial_loss(d_fake_outputs, torch.full((batch_size, 1), 0.4).type(FloatTensor))
        
        fake_data = generator(noise, 1)
        d_fake_outputs = discriminator(fake_data.detach())
        d_fake_loss2 = adversarial_loss(d_fake_outputs, torch.full((batch_size, 1), 0.6).type(FloatTensor))
        
        d_loss = d_real_loss + d_fake_loss1 + d_fake_loss2
        d_loss.backward()
        optimizer_D.step()
        
        # Train the generator
        optimizer_G.zero_grad()
        noise = torch.randn(batch_size, latent_dim)
        fake_data = generator(noise, 0)
        d_fake_outputs = discriminator(fake_data)
        targets = torch.full((batch_size, 1), 0)
        g_loss1 = adversarial_loss(d_fake_outputs, targets.float())

        noise = torch.randn(batch_size, latent_dim)
        fake_data = generator(noise, 1)
        d_fake_outputs = discriminator(fake_data)
        targets = torch.full((batch_size, 1), 1)
        g_loss2 = adversarial_loss(d_fake_outputs, targets.float())
        
        g_loss = g_loss1 + g_loss2
        g_loss.backward()
        optimizer_G.step()
        

        # Print the loss for each epoch
        if i % 1000 == 0:
            print("[Epoch %d/%d] [Batch %d/%d] [D loss: %f] [G loss: %f]" % (epoch, num_epochs, i, len(dataloader), d_loss.item(), g_loss.item()))

    print('Saving models...')
    # save discriminator model used for classification
    PATH_disc = './models/discr_model-'
    PATH = PATH_disc + 'lr=' + str(lr) + '-batch=' + str(batch_size) + '-epochs=' + str(epoch) + '.pth'
    torch.save(discriminator.state_dict(), PATH)
    
    # save generator model
    PATH_gen = './models/gen_model-'
    PATH = PATH_gen + 'lr=' + str(lr) + '-batch=' + str(batch_size) + '-epochs=' + str(epoch) + '.pth'
    torch.save(generator.state_dict(), PATH)
# Out:
# [Epoch 0/100] [Batch 0/4370] [D loss: 2.282337] [G loss: 1.421607]
# [Epoch 0/100] [Batch 1000/4370] [D loss: 1.834596] [G loss: 1.171569]
# [Epoch 0/100] [Batch 2000/4370] [D loss: 1.640155] [G loss: 1.028460]
# [Epoch 0/100] [Batch 3000/4370] [D loss: 1.808610] [G loss: 0.949630]
# [Epoch 0/100] [Batch 4000/4370] [D loss: 1.783948] [G loss: 0.874315]
# Saving models...
# [Epoch 1/100] [Batch 0/4370] [D loss: 1.818935] [G loss: 0.877385]
# [Epoch 1/100] [Batch 1000/4370] [D loss: 1.838374] [G loss: 0.880888]
# [Epoch 1/100] [Batch 2000/4370] [D loss: 1.776762] [G loss: 0.872039]
# [Epoch 1/100] [Batch 3000/4370] [D loss: 1.791757] [G loss: 0.866567]
# [Epoch 1/100] [Batch 4000/4370] [D loss: 1.815987] [G loss: 0.834597]
# Saving models...
# [Epoch 2/100] [Batch 0/4370] [D loss: 1.880446] [G loss: 0.828998]
# [Epoch 2/100] [Batch 1000/4370] [D loss: 1.782656] [G loss: 0.824654]
# [Epoch 2/100] [Batch 2000/4370] [D loss: 1.819453] [G loss: 0.824902]
# [Epoch 2/100] [Batch 3000/4370] [D loss: 1.778260] [G loss: 0.819222]
# [Epoch 2/100] [Batch 4000/4370] [D loss: 1.835494] [G loss: 0.806820]
# Saving models...
# [Epoch 3/100] [Batch 0/4370] [D loss: 1.842627] [G loss: 0.826005]
# [Epoch 3/100] [Batch 1000/4370] [D loss: 1.825561] [G loss: 0.807181]
# [Epoch 3/100] [Batch 2000/4370] [D loss: 1.804338] [G loss: 0.807098]
# [Epoch 3/100] [Batch 3000/4370] [D loss: 1.788682] [G loss: 0.820643]
# [Epoch 3/100] [Batch 4000/4370] [D loss: 1.848058] [G loss: 0.798532]
# Saving models...
# [Epoch 4/100] [Batch 0/4370] [D loss: 1.867497] [G loss: 0.777027]
# [Epoch 4/100] [Batch 1000/4370] [D loss: 1.824926] [G loss: 0.795009]
# [Epoch 4/100] [Batch 2000/4370] [D loss: 1.756655] [G loss: 0.801651]
# [Epoch 4/100] [Batch 3000/4370] [D loss: 1.824731] [G loss: 0.796426]
# [Epoch 4/100] [Batch 4000/4370] [D loss: 1.794558] [G loss: 0.797272]
# Saving models...
# [Epoch 5/100] [Batch 0/4370] [D loss: 1.807194] [G loss: 0.800029]
# [Epoch 5/100] [Batch 1000/4370] [D loss: 1.788917] [G loss: 0.796617]
# [Epoch 5/100] [Batch 2000/4370] [D loss: 1.801784] [G loss: 0.794225]
# [Epoch 5/100] [Batch 3000/4370] [D loss: 1.804232] [G loss: 0.783784]
# [Epoch 5/100] [Batch 4000/4370] [D loss: 1.845428] [G loss: 0.792863]
# Saving models...
# [Epoch 6/100] [Batch 0/4370] [D loss: 1.854217] [G loss: 0.788350]
# [Epoch 6/100] [Batch 1000/4370] [D loss: 1.792016] [G loss: 0.788529]
# [Epoch 6/100] [Batch 2000/4370] [D loss: 1.762941] [G loss: 0.801215]
# [Epoch 6/100] [Batch 3000/4370] [D loss: 1.750399] [G loss: 0.786650]
# [Epoch 6/100] [Batch 4000/4370] [D loss: 1.817748] [G loss: 0.759985]
# Saving models...
# [Epoch 7/100] [Batch 0/4370] [D loss: 1.752105] [G loss: 0.786495]
# [Epoch 7/100] [Batch 1000/4370] [D loss: 1.882216] [G loss: 0.871960]
# [Epoch 7/100] [Batch 2000/4370] [D loss: 1.795243] [G loss: 0.837728]
# [Epoch 7/100] [Batch 3000/4370] [D loss: 1.876485] [G loss: 0.804894]
# [Epoch 7/100] [Batch 4000/4370] [D loss: 1.781090] [G loss: 0.803513]
# Saving models...
# [Epoch 8/100] [Batch 0/4370] [D loss: 1.724728] [G loss: 0.796990]
# [Epoch 8/100] [Batch 1000/4370] [D loss: 1.819876] [G loss: 0.793238]
# [Epoch 8/100] [Batch 2000/4370] [D loss: 1.818084] [G loss: 0.803323]
# [Epoch 8/100] [Batch 3000/4370] [D loss: 1.799301] [G loss: 0.797158]
# [Epoch 8/100] [Batch 4000/4370] [D loss: 1.815723] [G loss: 0.830994]
# Saving models...
# [Epoch 9/100] [Batch 0/4370] [D loss: 1.808349] [G loss: 0.806781]
# [Epoch 9/100] [Batch 1000/4370] [D loss: 1.791272] [G loss: 0.806661]
# [Epoch 9/100] [Batch 2000/4370] [D loss: 1.784070] [G loss: 0.787390]
# [Epoch 9/100] [Batch 3000/4370] [D loss: 1.800389] [G loss: 0.786207]
# [Epoch 9/100] [Batch 4000/4370] [D loss: 1.808480] [G loss: 0.792697]
# Saving models...
# [Epoch 10/100] [Batch 0/4370] [D loss: 1.837718] [G loss: 0.791256]
# [Epoch 10/100] [Batch 1000/4370] [D loss: 1.875950] [G loss: 0.795479]
# [Epoch 10/100] [Batch 2000/4370] [D loss: 1.760182] [G loss: 0.789835]
# [Epoch 10/100] [Batch 3000/4370] [D loss: 1.806600] [G loss: 0.791646]
# [Epoch 10/100] [Batch 4000/4370] [D loss: 1.836761] [G loss: 0.789590]
# Saving models...
# [Epoch 11/100] [Batch 0/4370] [D loss: 1.793516] [G loss: 0.778824]
# [Epoch 11/100] [Batch 1000/4370] [D loss: 1.841477] [G loss: 0.790680]
# [Epoch 11/100] [Batch 2000/4370] [D loss: 1.761253] [G loss: 0.793643]
# [Epoch 11/100] [Batch 3000/4370] [D loss: 1.767281] [G loss: 0.791310]
# [Epoch 11/100] [Batch 4000/4370] [D loss: 1.826964] [G loss: 0.794946]
# Saving models...
# [Epoch 12/100] [Batch 0/4370] [D loss: 1.810472] [G loss: 0.775456]
# [Epoch 12/100] [Batch 1000/4370] [D loss: 1.797280] [G loss: 0.782181]
# [Epoch 12/100] [Batch 2000/4370] [D loss: 1.750539] [G loss: 0.777069]
# [Epoch 12/100] [Batch 3000/4370] [D loss: 1.820076] [G loss: 0.785066]
# [Epoch 12/100] [Batch 4000/4370] [D loss: 1.854801] [G loss: 0.786234]
# Saving models...
# [Epoch 13/100] [Batch 0/4370] [D loss: 1.786127] [G loss: 0.783284]
# [Epoch 13/100] [Batch 1000/4370] [D loss: 1.762044] [G loss: 0.786050]
# [Epoch 13/100] [Batch 2000/4370] [D loss: 1.829473] [G loss: 0.778928]
# [Epoch 13/100] [Batch 3000/4370] [D loss: 1.822513] [G loss: 0.778803]
# [Epoch 13/100] [Batch 4000/4370] [D loss: 1.797551] [G loss: 0.782339]
# Saving models...
# [Epoch 14/100] [Batch 0/4370] [D loss: 1.829081] [G loss: 0.778762]
# [Epoch 14/100] [Batch 1000/4370] [D loss: 1.775826] [G loss: 0.807492]
# [Epoch 14/100] [Batch 2000/4370] [D loss: 1.765097] [G loss: 0.774776]
# [Epoch 14/100] [Batch 3000/4370] [D loss: 1.806702] [G loss: 0.751788]
# [Epoch 14/100] [Batch 4000/4370] [D loss: 2.073243] [G loss: 0.693214]
# Saving models...
# [Epoch 15/100] [Batch 0/4370] [D loss: 2.066276] [G loss: 0.646173]
# [Epoch 15/100] [Batch 1000/4370] [D loss: 1.757454] [G loss: 0.809675]
# [Epoch 15/100] [Batch 2000/4370] [D loss: 1.809410] [G loss: 0.842823]
# [Epoch 15/100] [Batch 3000/4370] [D loss: 1.824873] [G loss: 0.810106]
# [Epoch 15/100] [Batch 4000/4370] [D loss: 1.873858] [G loss: 0.806415]
# Saving models...
# [Epoch 16/100] [Batch 0/4370] [D loss: 1.823996] [G loss: 0.798925]
# [Epoch 16/100] [Batch 1000/4370] [D loss: 1.813107] [G loss: 0.791206]
# [Epoch 16/100] [Batch 2000/4370] [D loss: 1.804886] [G loss: 0.789993]
# [Epoch 16/100] [Batch 3000/4370] [D loss: 1.830572] [G loss: 0.780400]
# [Epoch 16/100] [Batch 4000/4370] [D loss: 1.825133] [G loss: 0.793106]
# Saving models...
# [Epoch 17/100] [Batch 0/4370] [D loss: 1.828429] [G loss: 0.782195]
# [Epoch 17/100] [Batch 1000/4370] [D loss: 1.743763] [G loss: 0.805821]
# [Epoch 17/100] [Batch 2000/4370] [D loss: 1.849843] [G loss: 0.789454]
# [Epoch 17/100] [Batch 3000/4370] [D loss: 1.799635] [G loss: 0.792556]
# [Epoch 17/100] [Batch 4000/4370] [D loss: 1.765704] [G loss: 0.781492]
# Saving models...
# [Epoch 18/100] [Batch 0/4370] [D loss: 1.772068] [G loss: 0.778837]
# [Epoch 18/100] [Batch 1000/4370] [D loss: 1.785595] [G loss: 0.813267]
# [Epoch 18/100] [Batch 2000/4370] [D loss: 1.810205] [G loss: 0.789934]
# [Epoch 18/100] [Batch 3000/4370] [D loss: 1.739001] [G loss: 0.786096]
# [Epoch 18/100] [Batch 4000/4370] [D loss: 1.835667] [G loss: 0.792865]
# Saving models...
# [Epoch 19/100] [Batch 0/4370] [D loss: 1.783883] [G loss: 0.800105]
# [Epoch 19/100] [Batch 1000/4370] [D loss: 1.794714] [G loss: 0.783236]
# [Epoch 19/100] [Batch 2000/4370] [D loss: 1.888014] [G loss: 0.793858]
# [Epoch 19/100] [Batch 3000/4370] [D loss: 1.836930] [G loss: 0.791403]
# [Epoch 19/100] [Batch 4000/4370] [D loss: 1.797598] [G loss: 0.798282]
# Saving models...
# [Epoch 20/100] [Batch 0/4370] [D loss: 1.798035] [G loss: 0.788607]
# [Epoch 20/100] [Batch 1000/4370] [D loss: 1.849105] [G loss: 0.777223]
# [Epoch 20/100] [Batch 2000/4370] [D loss: 1.804363] [G loss: 0.772618]
# [Epoch 20/100] [Batch 3000/4370] [D loss: 1.799303] [G loss: 0.793380]
# [Epoch 20/100] [Batch 4000/4370] [D loss: 1.803144] [G loss: 0.789408]
# Saving models...
# [Epoch 21/100] [Batch 0/4370] [D loss: 1.866728] [G loss: 0.806657]
# [Epoch 21/100] [Batch 1000/4370] [D loss: 1.800958] [G loss: 0.790254]
# [Epoch 21/100] [Batch 2000/4370] [D loss: 1.788397] [G loss: 0.783229]
# [Epoch 21/100] [Batch 3000/4370] [D loss: 1.814989] [G loss: 0.784938]
# [Epoch 21/100] [Batch 4000/4370] [D loss: 1.781345] [G loss: 0.781134]
# Saving models...
# [Epoch 22/100] [Batch 0/4370] [D loss: 1.792041] [G loss: 0.778663]
# [Epoch 22/100] [Batch 1000/4370] [D loss: 1.855595] [G loss: 0.789709]
# [Epoch 22/100] [Batch 2000/4370] [D loss: 1.815542] [G loss: 0.788547]
# [Epoch 22/100] [Batch 3000/4370] [D loss: 1.789431] [G loss: 0.784699]
# [Epoch 22/100] [Batch 4000/4370] [D loss: 1.778875] [G loss: 0.792857]
# Saving models...
# [Epoch 23/100] [Batch 0/4370] [D loss: 1.810908] [G loss: 0.787528]
# [Epoch 23/100] [Batch 1000/4370] [D loss: 1.816975] [G loss: 0.789334]
# [Epoch 23/100] [Batch 2000/4370] [D loss: 1.805963] [G loss: 0.778876]
# [Epoch 23/100] [Batch 3000/4370] [D loss: 1.796752] [G loss: 0.799702]
# [Epoch 23/100] [Batch 4000/4370] [D loss: 1.811496] [G loss: 0.791632]
# Saving models...
# [Epoch 24/100] [Batch 0/4370] [D loss: 1.770394] [G loss: 0.785801]
# [Epoch 24/100] [Batch 1000/4370] [D loss: 1.789388] [G loss: 0.760271]
# [Epoch 24/100] [Batch 2000/4370] [D loss: 1.825320] [G loss: 0.776462]
# [Epoch 24/100] [Batch 3000/4370] [D loss: 1.792686] [G loss: 0.785081]
# [Epoch 24/100] [Batch 4000/4370] [D loss: 1.831736] [G loss: 0.781517]
# Saving models...
# [Epoch 25/100] [Batch 0/4370] [D loss: 1.748924] [G loss: 0.778709]
# [Epoch 25/100] [Batch 1000/4370] [D loss: 1.924699] [G loss: 0.760288]
# [Epoch 25/100] [Batch 2000/4370] [D loss: 1.832124] [G loss: 0.793835]
# [Epoch 25/100] [Batch 3000/4370] [D loss: 1.853947] [G loss: 0.811408]
# [Epoch 25/100] [Batch 4000/4370] [D loss: 1.808441] [G loss: 0.799014]
# Saving models...
# [Epoch 26/100] [Batch 0/4370] [D loss: 1.812652] [G loss: 0.810893]
# [Epoch 26/100] [Batch 1000/4370] [D loss: 1.798926] [G loss: 0.839391]
# [Epoch 26/100] [Batch 2000/4370] [D loss: 1.830637] [G loss: 0.775206]
# [Epoch 26/100] [Batch 3000/4370] [D loss: 1.843963] [G loss: 0.801695]
# [Epoch 26/100] [Batch 4000/4370] [D loss: 1.834345] [G loss: 0.821310]
# Saving models...
# [Epoch 27/100] [Batch 0/4370] [D loss: 1.907422] [G loss: 0.816875]
# [Epoch 27/100] [Batch 1000/4370] [D loss: 1.810156] [G loss: 0.810029]
# [Epoch 27/100] [Batch 2000/4370] [D loss: 1.839843] [G loss: 0.769150]
# [Epoch 27/100] [Batch 3000/4370] [D loss: 1.821745] [G loss: 0.793356]
# [Epoch 27/100] [Batch 4000/4370] [D loss: 1.810746] [G loss: 0.820220]
# Saving models...
# [Epoch 28/100] [Batch 0/4370] [D loss: 1.758942] [G loss: 0.757026]
# [Epoch 28/100] [Batch 1000/4370] [D loss: 1.828903] [G loss: 0.781283]
# [Epoch 28/100] [Batch 2000/4370] [D loss: 1.834060] [G loss: 0.792333]
# [Epoch 28/100] [Batch 3000/4370] [D loss: 1.749660] [G loss: 0.780900]
# [Epoch 28/100] [Batch 4000/4370] [D loss: 1.802990] [G loss: 0.776061]
# Saving models...
# [Epoch 29/100] [Batch 0/4370] [D loss: 1.816598] [G loss: 0.792212]
# [Epoch 29/100] [Batch 1000/4370] [D loss: 1.781291] [G loss: 0.768306]
# [Epoch 29/100] [Batch 2000/4370] [D loss: 1.800619] [G loss: 0.768596]
# [Epoch 29/100] [Batch 3000/4370] [D loss: 1.800149] [G loss: 0.762119]
# [Epoch 29/100] [Batch 4000/4370] [D loss: 1.736890] [G loss: 0.764103]
# Saving models...
# [Epoch 30/100] [Batch 0/4370] [D loss: 1.768087] [G loss: 0.771006]
# [Epoch 30/100] [Batch 1000/4370] [D loss: 1.773414] [G loss: 0.768705]
# [Epoch 30/100] [Batch 2000/4370] [D loss: 1.827251] [G loss: 0.773815]
# [Epoch 30/100] [Batch 3000/4370] [D loss: 1.803342] [G loss: 0.778513]
# [Epoch 30/100] [Batch 4000/4370] [D loss: 1.784764] [G loss: 0.762519]
# Saving models...
# [Epoch 31/100] [Batch 0/4370] [D loss: 1.793219] [G loss: 0.763578]
# [Epoch 31/100] [Batch 1000/4370] [D loss: 1.775282] [G loss: 0.761251]
# [Epoch 31/100] [Batch 2000/4370] [D loss: 1.744232] [G loss: 0.763773]
# [Epoch 31/100] [Batch 3000/4370] [D loss: 1.802196] [G loss: 0.744693]
# [Epoch 31/100] [Batch 4000/4370] [D loss: 1.807794] [G loss: 0.774492]
# Saving models...
# [Epoch 32/100] [Batch 0/4370] [D loss: 1.762772] [G loss: 0.769801]
# [Epoch 32/100] [Batch 1000/4370] [D loss: 1.870685] [G loss: 0.770786]
# [Epoch 32/100] [Batch 2000/4370] [D loss: 1.767597] [G loss: 0.774879]
# [Epoch 32/100] [Batch 3000/4370] [D loss: 1.781157] [G loss: 0.750712]
# [Epoch 32/100] [Batch 4000/4370] [D loss: 1.816294] [G loss: 0.746736]
# Saving models...
# [Epoch 33/100] [Batch 0/4370] [D loss: 1.801127] [G loss: 0.748802]
# [Epoch 33/100] [Batch 1000/4370] [D loss: 1.817302] [G loss: 0.755117]
# [Epoch 33/100] [Batch 2000/4370] [D loss: 1.745802] [G loss: 0.748966]
# [Epoch 33/100] [Batch 3000/4370] [D loss: 1.753210] [G loss: 0.752496]
# [Epoch 33/100] [Batch 4000/4370] [D loss: 1.783347] [G loss: 0.760060]
# Saving models...
# [Epoch 34/100] [Batch 0/4370] [D loss: 1.814017] [G loss: 0.761016]
# [Epoch 34/100] [Batch 1000/4370] [D loss: 1.727338] [G loss: 0.747130]
# [Epoch 34/100] [Batch 2000/4370] [D loss: 1.754435] [G loss: 0.764919]
# [Epoch 34/100] [Batch 3000/4370] [D loss: 1.729532] [G loss: 0.763340]
# [Epoch 34/100] [Batch 4000/4370] [D loss: 2.259995] [G loss: 0.721725]
# Saving models...
# [Epoch 35/100] [Batch 0/4370] [D loss: 2.000296] [G loss: 0.691583]
# [Epoch 35/100] [Batch 1000/4370] [D loss: 1.812876] [G loss: 1.034558]
# [Epoch 35/100] [Batch 2000/4370] [D loss: 1.852545] [G loss: 0.853643]
# [Epoch 35/100] [Batch 3000/4370] [D loss: 1.791751] [G loss: 0.864542]
# [Epoch 35/100] [Batch 4000/4370] [D loss: 1.852118] [G loss: 0.812676]
# Saving models...
# [Epoch 36/100] [Batch 0/4370] [D loss: 1.800984] [G loss: 0.769507]
# [Epoch 36/100] [Batch 1000/4370] [D loss: 1.808171] [G loss: 0.776840]
# [Epoch 36/100] [Batch 2000/4370] [D loss: 1.795009] [G loss: 0.784467]
# [Epoch 36/100] [Batch 3000/4370] [D loss: 1.821010] [G loss: 0.776834]
# [Epoch 36/100] [Batch 4000/4370] [D loss: 1.793655] [G loss: 0.771489]
# Saving models...
# [Epoch 37/100] [Batch 0/4370] [D loss: 1.797836] [G loss: 0.770637]
# [Epoch 37/100] [Batch 1000/4370] [D loss: 1.790829] [G loss: 0.774315]
# [Epoch 37/100] [Batch 2000/4370] [D loss: 1.824608] [G loss: 0.800382]
# [Epoch 37/100] [Batch 3000/4370] [D loss: 1.820761] [G loss: 0.800216]
# [Epoch 37/100] [Batch 4000/4370] [D loss: 1.778250] [G loss: 0.777356]
# Saving models...
# [Epoch 38/100] [Batch 0/4370] [D loss: 1.805400] [G loss: 0.780777]
# [Epoch 38/100] [Batch 1000/4370] [D loss: 1.837342] [G loss: 0.759092]
# [Epoch 38/100] [Batch 2000/4370] [D loss: 1.778973] [G loss: 0.777180]
# [Epoch 38/100] [Batch 3000/4370] [D loss: 1.810068] [G loss: 0.771061]
# [Epoch 38/100] [Batch 4000/4370] [D loss: 1.731918] [G loss: 0.778901]
# Saving models...
# [Epoch 39/100] [Batch 0/4370] [D loss: 1.711860] [G loss: 0.761108]
# [Epoch 39/100] [Batch 1000/4370] [D loss: 1.790908] [G loss: 0.774406]
# [Epoch 39/100] [Batch 2000/4370] [D loss: 1.774990] [G loss: 0.776013]
# [Epoch 39/100] [Batch 3000/4370] [D loss: 1.746512] [G loss: 0.763923]
# [Epoch 39/100] [Batch 4000/4370] [D loss: 1.779888] [G loss: 0.774952]
# Saving models...
# [Epoch 40/100] [Batch 0/4370] [D loss: 1.797350] [G loss: 0.770527]
# [Epoch 40/100] [Batch 1000/4370] [D loss: 1.811900] [G loss: 0.769705]
# [Epoch 40/100] [Batch 2000/4370] [D loss: 1.730035] [G loss: 0.788684]
# [Epoch 40/100] [Batch 3000/4370] [D loss: 1.774511] [G loss: 0.770072]
# [Epoch 40/100] [Batch 4000/4370] [D loss: 1.784617] [G loss: 0.767584]
# Saving models...
# [Epoch 41/100] [Batch 0/4370] [D loss: 1.769557] [G loss: 0.775170]
# [Epoch 41/100] [Batch 1000/4370] [D loss: 1.758776] [G loss: 0.766626]
# [Epoch 41/100] [Batch 2000/4370] [D loss: 1.813489] [G loss: 0.773934]
# [Epoch 41/100] [Batch 3000/4370] [D loss: 1.763232] [G loss: 0.768056]
# [Epoch 41/100] [Batch 4000/4370] [D loss: 1.743696] [G loss: 0.761501]
# Saving models...
# [Epoch 42/100] [Batch 0/4370] [D loss: 1.787536] [G loss: 0.763709]
# [Epoch 42/100] [Batch 1000/4370] [D loss: 1.836320] [G loss: 0.749503]
# [Epoch 42/100] [Batch 2000/4370] [D loss: 1.858140] [G loss: 0.729892]
# [Epoch 42/100] [Batch 3000/4370] [D loss: 1.794963] [G loss: 0.767360]
# [Epoch 42/100] [Batch 4000/4370] [D loss: 1.745406] [G loss: 0.752147]
# Saving models...
# [Epoch 43/100] [Batch 0/4370] [D loss: 1.768996] [G loss: 0.747088]
# [Epoch 43/100] [Batch 1000/4370] [D loss: 1.812871] [G loss: 0.755916]
# [Epoch 43/100] [Batch 2000/4370] [D loss: 1.762546] [G loss: 0.747184]
# [Epoch 43/100] [Batch 3000/4370] [D loss: 1.796459] [G loss: 0.755510]
# [Epoch 43/100] [Batch 4000/4370] [D loss: 1.829861] [G loss: 0.748462]
# Saving models...
# [Epoch 44/100] [Batch 0/4370] [D loss: 1.763524] [G loss: 0.751129]
# [Epoch 44/100] [Batch 1000/4370] [D loss: 1.857158] [G loss: 0.706103]
# [Epoch 44/100] [Batch 2000/4370] [D loss: 1.745441] [G loss: 0.754867]
# [Epoch 44/100] [Batch 3000/4370] [D loss: 1.758296] [G loss: 0.746632]
# [Epoch 44/100] [Batch 4000/4370] [D loss: 1.804743] [G loss: 0.748151]
# Saving models...
# [Epoch 45/100] [Batch 0/4370] [D loss: 1.784590] [G loss: 0.740501]
# [Epoch 45/100] [Batch 1000/4370] [D loss: 1.784766] [G loss: 0.749464]
# [Epoch 45/100] [Batch 2000/4370] [D loss: 1.764651] [G loss: 0.754486]
# [Epoch 45/100] [Batch 3000/4370] [D loss: 1.760908] [G loss: 0.729938]
# [Epoch 45/100] [Batch 4000/4370] [D loss: 1.745988] [G loss: 0.744619]
# Saving models...
# [Epoch 46/100] [Batch 0/4370] [D loss: 1.777377] [G loss: 0.759353]
# [Epoch 46/100] [Batch 1000/4370] [D loss: 1.781351] [G loss: 0.767498]
# [Epoch 46/100] [Batch 2000/4370] [D loss: 1.736867] [G loss: 0.752715]
# [Epoch 46/100] [Batch 3000/4370] [D loss: 1.803426] [G loss: 0.738704]
# [Epoch 46/100] [Batch 4000/4370] [D loss: 1.757254] [G loss: 0.752560]
# Saving models...
# [Epoch 47/100] [Batch 0/4370] [D loss: 1.799058] [G loss: 0.744024]
# [Epoch 47/100] [Batch 1000/4370] [D loss: 1.789459] [G loss: 0.760626]
# [Epoch 47/100] [Batch 2000/4370] [D loss: 1.771060] [G loss: 0.749882]
# [Epoch 47/100] [Batch 3000/4370] [D loss: 1.762708] [G loss: 0.770972]
# [Epoch 47/100] [Batch 4000/4370] [D loss: 1.744456] [G loss: 0.762295]
# Saving models...
# [Epoch 48/100] [Batch 0/4370] [D loss: 1.756420] [G loss: 0.764182]
# [Epoch 48/100] [Batch 1000/4370] [D loss: 1.788682] [G loss: 0.741705]
# [Epoch 48/100] [Batch 2000/4370] [D loss: 1.751355] [G loss: 0.750889]
# [Epoch 48/100] [Batch 3000/4370] [D loss: 1.769908] [G loss: 0.752017]
# [Epoch 48/100] [Batch 4000/4370] [D loss: 1.810652] [G loss: 0.751798]
# Saving models...
# [Epoch 49/100] [Batch 0/4370] [D loss: 1.770877] [G loss: 0.755417]
# [Epoch 49/100] [Batch 1000/4370] [D loss: 1.806306] [G loss: 0.781906]
# [Epoch 49/100] [Batch 2000/4370] [D loss: 1.762985] [G loss: 0.764473]
# [Epoch 49/100] [Batch 3000/4370] [D loss: 1.810901] [G loss: 0.763526]
# [Epoch 49/100] [Batch 4000/4370] [D loss: 1.756584] [G loss: 0.761277]
# Saving models...
# [Epoch 50/100] [Batch 0/4370] [D loss: 1.765396] [G loss: 0.759090]
# [Epoch 50/100] [Batch 1000/4370] [D loss: 1.744729] [G loss: 0.773767]
# [Epoch 50/100] [Batch 2000/4370] [D loss: 1.765639] [G loss: 0.762067]
# [Epoch 50/100] [Batch 3000/4370] [D loss: 1.786876] [G loss: 0.741635]
# [Epoch 50/100] [Batch 4000/4370] [D loss: 1.805016] [G loss: 0.743231]
# Saving models...
# [Epoch 51/100] [Batch 0/4370] [D loss: 1.722828] [G loss: 0.753816]
# [Epoch 51/100] [Batch 1000/4370] [D loss: 1.798199] [G loss: 0.754736]
# [Epoch 51/100] [Batch 2000/4370] [D loss: 1.789927] [G loss: 0.763436]
# [Epoch 51/100] [Batch 3000/4370] [D loss: 1.757030] [G loss: 0.753050]
# [Epoch 51/100] [Batch 4000/4370] [D loss: 1.753882] [G loss: 0.752270]
# Saving models...
# [Epoch 52/100] [Batch 0/4370] [D loss: 1.748971] [G loss: 0.767714]
# [Epoch 52/100] [Batch 1000/4370] [D loss: 1.781054] [G loss: 0.750546]
# [Epoch 52/100] [Batch 2000/4370] [D loss: 1.744202] [G loss: 0.757166]
# [Epoch 52/100] [Batch 3000/4370] [D loss: 1.787666] [G loss: 0.752663]
# [Epoch 52/100] [Batch 4000/4370] [D loss: 1.756248] [G loss: 0.748055]
# Saving models...
# [Epoch 53/100] [Batch 0/4370] [D loss: 1.752222] [G loss: 0.753974]
# [Epoch 53/100] [Batch 1000/4370] [D loss: 1.751335] [G loss: 0.769964]
# [Epoch 53/100] [Batch 2000/4370] [D loss: 1.722465] [G loss: 0.757119]
# [Epoch 53/100] [Batch 3000/4370] [D loss: 1.763233] [G loss: 0.781115]
# [Epoch 53/100] [Batch 4000/4370] [D loss: 1.741803] [G loss: 0.783667]
# Saving models...
# [Epoch 54/100] [Batch 0/4370] [D loss: 1.806354] [G loss: 0.762586]
# [Epoch 54/100] [Batch 1000/4370] [D loss: 1.799348] [G loss: 0.753298]
# [Epoch 54/100] [Batch 2000/4370] [D loss: 1.780335] [G loss: 0.755968]
# [Epoch 54/100] [Batch 3000/4370] [D loss: 1.734833] [G loss: 0.760289]
# [Epoch 54/100] [Batch 4000/4370] [D loss: 1.752100] [G loss: 0.770014]
# Saving models...
# [Epoch 55/100] [Batch 0/4370] [D loss: 1.765137] [G loss: 0.768453]
# [Epoch 55/100] [Batch 1000/4370] [D loss: 1.786785] [G loss: 0.763942]
# [Epoch 55/100] [Batch 2000/4370] [D loss: 1.747803] [G loss: 0.754574]
# [Epoch 55/100] [Batch 3000/4370] [D loss: 1.785281] [G loss: 0.766343]
# [Epoch 55/100] [Batch 4000/4370] [D loss: 1.841438] [G loss: 0.753892]
# Saving models...
# [Epoch 56/100] [Batch 0/4370] [D loss: 1.787064] [G loss: 0.726447]
# [Epoch 56/100] [Batch 1000/4370] [D loss: 1.766023] [G loss: 0.763466]
# [Epoch 56/100] [Batch 2000/4370] [D loss: 1.736561] [G loss: 0.767675]
# [Epoch 56/100] [Batch 3000/4370] [D loss: 1.774231] [G loss: 0.758150]
# [Epoch 56/100] [Batch 4000/4370] [D loss: 1.774103] [G loss: 0.767220]
# Saving models...
# [Epoch 57/100] [Batch 0/4370] [D loss: 1.784647] [G loss: 0.768423]
# [Epoch 57/100] [Batch 1000/4370] [D loss: 1.772371] [G loss: 0.749494]
# [Epoch 57/100] [Batch 2000/4370] [D loss: 1.805107] [G loss: 0.765644]
# [Epoch 57/100] [Batch 3000/4370] [D loss: 1.761127] [G loss: 0.757343]
# [Epoch 57/100] [Batch 4000/4370] [D loss: 1.749755] [G loss: 0.766515]
# Saving models...
# [Epoch 58/100] [Batch 0/4370] [D loss: 1.776210] [G loss: 0.758856]
# [Epoch 58/100] [Batch 1000/4370] [D loss: 1.790170] [G loss: 0.764838]
# [Epoch 58/100] [Batch 2000/4370] [D loss: 1.763007] [G loss: 0.759396]
# [Epoch 58/100] [Batch 3000/4370] [D loss: 1.831169] [G loss: 0.761895]
# [Epoch 58/100] [Batch 4000/4370] [D loss: 1.748262] [G loss: 0.770761]
# Saving models...
# [Epoch 59/100] [Batch 0/4370] [D loss: 1.709159] [G loss: 0.757677]
# [Epoch 59/100] [Batch 1000/4370] [D loss: 1.743815] [G loss: 0.755183]
# [Epoch 59/100] [Batch 2000/4370] [D loss: 1.796654] [G loss: 0.759186]
# [Epoch 59/100] [Batch 3000/4370] [D loss: 1.773052] [G loss: 0.756094]
# [Epoch 59/100] [Batch 4000/4370] [D loss: 1.815001] [G loss: 0.763033]
# Saving models...
# [Epoch 60/100] [Batch 0/4370] [D loss: 1.750808] [G loss: 0.757872]
# [Epoch 60/100] [Batch 1000/4370] [D loss: 1.762020] [G loss: 0.755045]
# [Epoch 60/100] [Batch 2000/4370] [D loss: 1.771299] [G loss: 0.772271]
# [Epoch 60/100] [Batch 3000/4370] [D loss: 1.765563] [G loss: 0.773710]
# [Epoch 60/100] [Batch 4000/4370] [D loss: 1.737712] [G loss: 0.754232]
# Saving models...
# [Epoch 61/100] [Batch 0/4370] [D loss: 1.813534] [G loss: 0.743425]
# [Epoch 61/100] [Batch 1000/4370] [D loss: 1.773493] [G loss: 0.634806]
# [Epoch 61/100] [Batch 2000/4370] [D loss: 1.705279] [G loss: 0.664102]
# [Epoch 61/100] [Batch 3000/4370] [D loss: 1.764783] [G loss: 0.690500]
# [Epoch 61/100] [Batch 4000/4370] [D loss: 1.760077] [G loss: 0.737479]
# Saving models...
# [Epoch 62/100] [Batch 0/4370] [D loss: 1.745279] [G loss: 0.758807]
# [Epoch 62/100] [Batch 1000/4370] [D loss: 1.788926] [G loss: 0.697496]
# [Epoch 62/100] [Batch 2000/4370] [D loss: 1.742368] [G loss: 0.736874]
# [Epoch 62/100] [Batch 3000/4370] [D loss: 1.702982] [G loss: 0.751398]
# [Epoch 62/100] [Batch 4000/4370] [D loss: 1.765433] [G loss: 0.772264]
# Saving models...
# [Epoch 63/100] [Batch 0/4370] [D loss: 1.752177] [G loss: 0.775531]
# [Epoch 63/100] [Batch 1000/4370] [D loss: 1.755880] [G loss: 0.777156]
# [Epoch 63/100] [Batch 2000/4370] [D loss: 1.762561] [G loss: 0.775105]
# [Epoch 63/100] [Batch 3000/4370] [D loss: 1.780607] [G loss: 0.774349]
# [Epoch 63/100] [Batch 4000/4370] [D loss: 1.747649] [G loss: 0.774062]
# Saving models...
# [Epoch 64/100] [Batch 0/4370] [D loss: 1.852248] [G loss: 0.725744]
# [Epoch 64/100] [Batch 1000/4370] [D loss: 1.826377] [G loss: 0.698496]
# [Epoch 64/100] [Batch 2000/4370] [D loss: 1.773257] [G loss: 0.731907]
# [Epoch 64/100] [Batch 3000/4370] [D loss: 1.775072] [G loss: 0.753311]
# [Epoch 64/100] [Batch 4000/4370] [D loss: 1.747669] [G loss: 0.781126]
# Saving models...
# [Epoch 65/100] [Batch 0/4370] [D loss: 1.766078] [G loss: 0.789976]
# [Epoch 65/100] [Batch 1000/4370] [D loss: 1.812634] [G loss: 0.773211]
# [Epoch 65/100] [Batch 2000/4370] [D loss: 1.739511] [G loss: 0.772522]
# [Epoch 65/100] [Batch 3000/4370] [D loss: 1.771615] [G loss: 0.777388]
# [Epoch 65/100] [Batch 4000/4370] [D loss: 1.734378] [G loss: 0.782600]
# Saving models...
# [Epoch 66/100] [Batch 0/4370] [D loss: 1.722266] [G loss: 0.775684]
# [Epoch 66/100] [Batch 1000/4370] [D loss: 1.799462] [G loss: 0.770912]
# [Epoch 66/100] [Batch 2000/4370] [D loss: 1.733691] [G loss: 0.747255]
# [Epoch 66/100] [Batch 3000/4370] [D loss: 1.734589] [G loss: 0.753486]
# [Epoch 66/100] [Batch 4000/4370] [D loss: 1.720803] [G loss: 0.754767]
# Saving models...
# [Epoch 67/100] [Batch 0/4370] [D loss: 1.734895] [G loss: 0.788244]
# [Epoch 67/100] [Batch 1000/4370] [D loss: 1.724293] [G loss: 0.767890]
# [Epoch 67/100] [Batch 2000/4370] [D loss: 1.800387] [G loss: 0.782480]
# [Epoch 67/100] [Batch 3000/4370] [D loss: 1.723970] [G loss: 0.738137]
# [Epoch 67/100] [Batch 4000/4370] [D loss: 1.800375] [G loss: 0.766035]
# Saving models...
# [Epoch 68/100] [Batch 0/4370] [D loss: 1.783197] [G loss: 0.761404]
# [Epoch 68/100] [Batch 1000/4370] [D loss: 1.726900] [G loss: 0.772850]
# [Epoch 68/100] [Batch 2000/4370] [D loss: 1.807756] [G loss: 0.793762]
# [Epoch 68/100] [Batch 3000/4370] [D loss: 1.754115] [G loss: 0.789736]
# [Epoch 68/100] [Batch 4000/4370] [D loss: 1.739049] [G loss: 0.790011]
# Saving models...
# [Epoch 69/100] [Batch 0/4370] [D loss: 1.777387] [G loss: 0.729627]
# [Epoch 69/100] [Batch 1000/4370] [D loss: 1.775150] [G loss: 0.769787]
# [Epoch 69/100] [Batch 2000/4370] [D loss: 1.759828] [G loss: 0.762993]
# [Epoch 69/100] [Batch 3000/4370] [D loss: 1.758014] [G loss: 0.785055]
# [Epoch 69/100] [Batch 4000/4370] [D loss: 1.740168] [G loss: 0.782091]
# Saving models...
# [Epoch 70/100] [Batch 0/4370] [D loss: 1.777157] [G loss: 0.774707]
# [Epoch 70/100] [Batch 1000/4370] [D loss: 1.758689] [G loss: 0.774878]
# [Epoch 70/100] [Batch 2000/4370] [D loss: 1.742039] [G loss: 0.765313]
# [Epoch 70/100] [Batch 3000/4370] [D loss: 1.786770] [G loss: 0.763228]
# [Epoch 70/100] [Batch 4000/4370] [D loss: 1.745821] [G loss: 0.789961]
# Saving models...
# [Epoch 71/100] [Batch 0/4370] [D loss: 1.688763] [G loss: 0.786616]
# [Epoch 71/100] [Batch 1000/4370] [D loss: 1.728807] [G loss: 0.789850]
# [Epoch 71/100] [Batch 2000/4370] [D loss: 1.739195] [G loss: 0.737542]
# [Epoch 71/100] [Batch 3000/4370] [D loss: 1.746531] [G loss: 0.733123]
# [Epoch 71/100] [Batch 4000/4370] [D loss: 1.761786] [G loss: 0.765532]
# Saving models...
# [Epoch 72/100] [Batch 0/4370] [D loss: 1.767211] [G loss: 0.771575]
# [Epoch 72/100] [Batch 1000/4370] [D loss: 1.732129] [G loss: 0.756873]
# [Epoch 72/100] [Batch 2000/4370] [D loss: 1.770512] [G loss: 0.755369]
# [Epoch 72/100] [Batch 3000/4370] [D loss: 1.732728] [G loss: 0.777127]
# [Epoch 72/100] [Batch 4000/4370] [D loss: 1.716540] [G loss: 0.777628]
# Saving models...
# [Epoch 73/100] [Batch 0/4370] [D loss: 1.722406] [G loss: 0.798656]
# [Epoch 73/100] [Batch 1000/4370] [D loss: 1.783870] [G loss: 0.769120]
# [Epoch 73/100] [Batch 2000/4370] [D loss: 1.744294] [G loss: 0.791676]
# [Epoch 73/100] [Batch 3000/4370] [D loss: 1.741592] [G loss: 0.767849]
# [Epoch 73/100] [Batch 4000/4370] [D loss: 1.699550] [G loss: 0.761263]
# Saving models...
# [Epoch 74/100] [Batch 0/4370] [D loss: 1.733035] [G loss: 0.834124]
# [Epoch 74/100] [Batch 1000/4370] [D loss: 1.802309] [G loss: 0.774478]
# [Epoch 74/100] [Batch 2000/4370] [D loss: 1.795472] [G loss: 0.726290]
# [Epoch 74/100] [Batch 3000/4370] [D loss: 1.720379] [G loss: 0.764615]
# [Epoch 74/100] [Batch 4000/4370] [D loss: 1.721954] [G loss: 0.770283]
# Saving models...
# [Epoch 75/100] [Batch 0/4370] [D loss: 1.745059] [G loss: 0.747438]
# [Epoch 75/100] [Batch 1000/4370] [D loss: 1.753833] [G loss: 0.756170]
# [Epoch 75/100] [Batch 2000/4370] [D loss: 1.756820] [G loss: 0.736941]
# [Epoch 75/100] [Batch 3000/4370] [D loss: 1.767617] [G loss: 0.788208]
# [Epoch 75/100] [Batch 4000/4370] [D loss: 1.775125] [G loss: 0.764422]
# Saving models...
# [Epoch 76/100] [Batch 0/4370] [D loss: 1.722243] [G loss: 0.763833]
# [Epoch 76/100] [Batch 1000/4370] [D loss: 1.740664] [G loss: 0.755659]
# [Epoch 76/100] [Batch 2000/4370] [D loss: 1.742360] [G loss: 0.770358]
# [Epoch 76/100] [Batch 3000/4370] [D loss: 1.780677] [G loss: 0.774354]
# [Epoch 76/100] [Batch 4000/4370] [D loss: 1.750154] [G loss: 0.793563]
# Saving models...
# [Epoch 77/100] [Batch 0/4370] [D loss: 1.715611] [G loss: 0.761355]
# [Epoch 77/100] [Batch 1000/4370] [D loss: 1.769013] [G loss: 0.753656]
# [Epoch 77/100] [Batch 2000/4370] [D loss: 1.700765] [G loss: 0.768915]
# [Epoch 77/100] [Batch 3000/4370] [D loss: 1.723939] [G loss: 0.806831]
# [Epoch 77/100] [Batch 4000/4370] [D loss: 1.750880] [G loss: 0.758556]
# Saving models...
# [Epoch 78/100] [Batch 0/4370] [D loss: 1.722869] [G loss: 0.741648]
# [Epoch 78/100] [Batch 1000/4370] [D loss: 1.675632] [G loss: 0.750122]
# [Epoch 78/100] [Batch 2000/4370] [D loss: 1.747134] [G loss: 0.777373]
# [Epoch 78/100] [Batch 3000/4370] [D loss: 1.734938] [G loss: 0.793334]
# [Epoch 78/100] [Batch 4000/4370] [D loss: 1.731408] [G loss: 0.762539]
# Saving models...
# [Epoch 79/100] [Batch 0/4370] [D loss: 1.792207] [G loss: 0.729967]
# [Epoch 79/100] [Batch 1000/4370] [D loss: 1.788195] [G loss: 0.722396]
# [Epoch 79/100] [Batch 2000/4370] [D loss: 1.788554] [G loss: 0.756689]
# [Epoch 79/100] [Batch 3000/4370] [D loss: 1.739251] [G loss: 0.743906]
# [Epoch 79/100] [Batch 4000/4370] [D loss: 1.779461] [G loss: 1.110624]
# Saving models...
# [Epoch 80/100] [Batch 0/4370] [D loss: 1.796039] [G loss: 0.764023]
# [Epoch 80/100] [Batch 1000/4370] [D loss: 1.737991] [G loss: 0.736869]
# [Epoch 80/100] [Batch 2000/4370] [D loss: 1.786450] [G loss: 0.727340]
# [Epoch 80/100] [Batch 3000/4370] [D loss: 1.752888] [G loss: 0.876190]
# [Epoch 80/100] [Batch 4000/4370] [D loss: 1.711660] [G loss: 0.717633]
# Saving models...
# [Epoch 81/100] [Batch 0/4370] [D loss: 1.750054] [G loss: 0.737211]
# [Epoch 81/100] [Batch 1000/4370] [D loss: 1.777127] [G loss: 0.729360]
# [Epoch 81/100] [Batch 2000/4370] [D loss: 1.775160] [G loss: 0.740894]
# [Epoch 81/100] [Batch 3000/4370] [D loss: 1.770603] [G loss: 0.720185]
# [Epoch 81/100] [Batch 4000/4370] [D loss: 1.711412] [G loss: 0.731435]
# Saving models...
# [Epoch 82/100] [Batch 0/4370] [D loss: 1.713408] [G loss: 0.744003]
# [Epoch 82/100] [Batch 1000/4370] [D loss: 1.798102] [G loss: 0.723187]
# [Epoch 82/100] [Batch 2000/4370] [D loss: 1.753889] [G loss: 0.751215]
# [Epoch 82/100] [Batch 3000/4370] [D loss: 1.731868] [G loss: 0.738115]
# [Epoch 82/100] [Batch 4000/4370] [D loss: 1.747882] [G loss: 0.739102]
# Saving models...
# [Epoch 83/100] [Batch 0/4370] [D loss: 1.742403] [G loss: 0.733126]
# [Epoch 83/100] [Batch 1000/4370] [D loss: 1.718898] [G loss: 0.742888]
# [Epoch 83/100] [Batch 2000/4370] [D loss: 1.753188] [G loss: 0.724150]
# [Epoch 83/100] [Batch 3000/4370] [D loss: 1.771470] [G loss: 0.744303]
# [Epoch 83/100] [Batch 4000/4370] [D loss: 1.750609] [G loss: 0.745588]
# Saving models...
# [Epoch 84/100] [Batch 0/4370] [D loss: 1.793630] [G loss: 0.755769]
# [Epoch 84/100] [Batch 1000/4370] [D loss: 1.790138] [G loss: 0.739598]
# [Epoch 84/100] [Batch 2000/4370] [D loss: 1.776256] [G loss: 0.728510]
# [Epoch 84/100] [Batch 3000/4370] [D loss: 1.747014] [G loss: 0.739226]
# [Epoch 84/100] [Batch 4000/4370] [D loss: 1.764846] [G loss: 0.743244]
# Saving models...
# [Epoch 85/100] [Batch 0/4370] [D loss: 1.737944] [G loss: 0.745793]
# [Epoch 85/100] [Batch 1000/4370] [D loss: 1.736511] [G loss: 0.743647]
# [Epoch 85/100] [Batch 2000/4370] [D loss: 3.333815] [G loss: 0.756657]
# [Epoch 85/100] [Batch 3000/4370] [D loss: 1.690824] [G loss: 0.747909]
# [Epoch 85/100] [Batch 4000/4370] [D loss: 1.757576] [G loss: 0.745952]
# Saving models...
# [Epoch 86/100] [Batch 0/4370] [D loss: 1.719727] [G loss: 0.725474]
# [Epoch 86/100] [Batch 1000/4370] [D loss: 1.797102] [G loss: 0.784114]
# [Epoch 86/100] [Batch 2000/4370] [D loss: 2.857829] [G loss: 0.696207]
# [Epoch 86/100] [Batch 3000/4370] [D loss: 7.390351] [G loss: 0.703695]
# [Epoch 86/100] [Batch 4000/4370] [D loss: 10.501707] [G loss: 0.795212]
# Saving models...
# [Epoch 87/100] [Batch 0/4370] [D loss: 11.614935] [G loss: 0.651312]
# [Epoch 87/100] [Batch 1000/4370] [D loss: 13.963810] [G loss: 0.673774]
# [Epoch 87/100] [Batch 2000/4370] [D loss: 15.237804] [G loss: 0.651522]
# [Epoch 87/100] [Batch 3000/4370] [D loss: 14.719278] [G loss: 0.672463]
# [Epoch 87/100] [Batch 4000/4370] [D loss: 14.617841] [G loss: 0.686703]
# Saving models...
# [Epoch 88/100] [Batch 0/4370] [D loss: 17.090622] [G loss: 0.635359]
# [Epoch 88/100] [Batch 1000/4370] [D loss: 15.932870] [G loss: 0.729068]
# [Epoch 88/100] [Batch 2000/4370] [D loss: 18.301964] [G loss: 0.647698]
# [Epoch 88/100] [Batch 3000/4370] [D loss: 18.928928] [G loss: 0.639390]
# [Epoch 88/100] [Batch 4000/4370] [D loss: 16.489494] [G loss: 0.574904]
# Saving models...
# [Epoch 89/100] [Batch 0/4370] [D loss: 20.120768] [G loss: 0.591205]
# [Epoch 89/100] [Batch 1000/4370] [D loss: 20.180349] [G loss: 0.628177]
# [Epoch 89/100] [Batch 2000/4370] [D loss: 18.919241] [G loss: 0.629173]
# [Epoch 89/100] [Batch 3000/4370] [D loss: 5.208701] [G loss: 0.611924]
# [Epoch 89/100] [Batch 4000/4370] [D loss: 1.862876] [G loss: 0.762123]
# Saving models...
# [Epoch 90/100] [Batch 0/4370] [D loss: 1.736363] [G loss: 0.884056]
# [Epoch 90/100] [Batch 1000/4370] [D loss: 1.748607] [G loss: 0.827818]
# [Epoch 90/100] [Batch 2000/4370] [D loss: 1.846481] [G loss: 0.792822]
# [Epoch 90/100] [Batch 3000/4370] [D loss: 1.738091] [G loss: 0.754048]
# [Epoch 90/100] [Batch 4000/4370] [D loss: 1.775902] [G loss: 0.833990]
# Saving models...
# [Epoch 91/100] [Batch 0/4370] [D loss: 1.778000] [G loss: 0.843491]
# [Epoch 91/100] [Batch 1000/4370] [D loss: 1.767647] [G loss: 0.848905]
# [Epoch 91/100] [Batch 2000/4370] [D loss: 1.744597] [G loss: 0.775676]
# [Epoch 91/100] [Batch 3000/4370] [D loss: 1.699429] [G loss: 0.806970]
# [Epoch 91/100] [Batch 4000/4370] [D loss: 1.758446] [G loss: 0.834532]
# Saving models...
# [Epoch 92/100] [Batch 0/4370] [D loss: 1.756005] [G loss: 0.819986]
# [Epoch 92/100] [Batch 1000/4370] [D loss: 1.792330] [G loss: 0.799626]
# [Epoch 92/100] [Batch 2000/4370] [D loss: 1.793988] [G loss: 0.815953]
# [Epoch 92/100] [Batch 3000/4370] [D loss: 1.722960] [G loss: 0.868039]
# [Epoch 92/100] [Batch 4000/4370] [D loss: 1.750190] [G loss: 0.837970]
# Saving models...
# [Epoch 93/100] [Batch 0/4370] [D loss: 1.776098] [G loss: 0.812590]
# [Epoch 93/100] [Batch 1000/4370] [D loss: 1.811481] [G loss: 0.812851]
# [Epoch 93/100] [Batch 2000/4370] [D loss: 1.723619] [G loss: 0.794263]
# [Epoch 93/100] [Batch 3000/4370] [D loss: 1.756793] [G loss: 0.799591]
# [Epoch 93/100] [Batch 4000/4370] [D loss: 1.813777] [G loss: 0.873749]
# Saving models...
# [Epoch 94/100] [Batch 0/4370] [D loss: 1.752562] [G loss: 0.790558]
# [Epoch 94/100] [Batch 1000/4370] [D loss: 1.747153] [G loss: 0.792520]
# [Epoch 94/100] [Batch 2000/4370] [D loss: 1.751860] [G loss: 0.776731]
# [Epoch 94/100] [Batch 3000/4370] [D loss: 1.695561] [G loss: 0.846853]
# [Epoch 94/100] [Batch 4000/4370] [D loss: 1.703198] [G loss: 0.791522]
# Saving models...
# [Epoch 95/100] [Batch 0/4370] [D loss: 1.762932] [G loss: 0.766187]
# [Epoch 95/100] [Batch 1000/4370] [D loss: 1.693290] [G loss: 0.773555]
# [Epoch 95/100] [Batch 2000/4370] [D loss: 1.813740] [G loss: 0.803110]
# [Epoch 95/100] [Batch 3000/4370] [D loss: 1.891356] [G loss: 0.788059]
# [Epoch 95/100] [Batch 4000/4370] [D loss: 1.775316] [G loss: 0.893812]
# Saving models...
# [Epoch 96/100] [Batch 0/4370] [D loss: 1.781494] [G loss: 0.914338]
# [Epoch 96/100] [Batch 1000/4370] [D loss: 1.666448] [G loss: 0.920944]
# [Epoch 96/100] [Batch 2000/4370] [D loss: 1.696266] [G loss: 0.907616]
# [Epoch 96/100] [Batch 3000/4370] [D loss: 1.723397] [G loss: 0.874747]
# [Epoch 96/100] [Batch 4000/4370] [D loss: 1.684595] [G loss: 0.866124]
# Saving models...
# [Epoch 97/100] [Batch 0/4370] [D loss: 1.694485] [G loss: 0.883091]
# [Epoch 97/100] [Batch 1000/4370] [D loss: 1.721878] [G loss: 0.888050]
# [Epoch 97/100] [Batch 2000/4370] [D loss: 1.713786] [G loss: 0.849382]
# [Epoch 97/100] [Batch 3000/4370] [D loss: 1.650955] [G loss: 0.837918]
# [Epoch 97/100] [Batch 4000/4370] [D loss: 1.731422] [G loss: 0.848182]
# Saving models...
# [Epoch 98/100] [Batch 0/4370] [D loss: 1.675488] [G loss: 0.851784]
# [Epoch 98/100] [Batch 1000/4370] [D loss: 1.752093] [G loss: 0.863040]
# [Epoch 98/100] [Batch 2000/4370] [D loss: 1.689335] [G loss: 0.820865]
# [Epoch 98/100] [Batch 3000/4370] [D loss: 1.737688] [G loss: 0.834655]
# [Epoch 98/100] [Batch 4000/4370] [D loss: 1.802682] [G loss: 0.821838]
# Saving models...
# [Epoch 99/100] [Batch 0/4370] [D loss: 1.721540] [G loss: 0.813910]
# [Epoch 99/100] [Batch 1000/4370] [D loss: 1.713308] [G loss: 0.860396]
# [Epoch 99/100] [Batch 2000/4370] [D loss: 1.732199] [G loss: 0.823817]
# [Epoch 99/100] [Batch 3000/4370] [D loss: 1.760302] [G loss: 0.800682]
# [Epoch 99/100] [Batch 4000/4370] [D loss: 1.739283] [G loss: 0.791998]
# Saving models...
