# %%
import pandas as pd
import joblib
import numpy as np
from sklearn.impute import SimpleImputer
from tabulate import tabulate

#cicdataset = pd.read_csv('C:/Users/katsa/Documents/cicids2017.csv')
cicdataset = pd.read_csv("C:/Users/katsa/OneDrive/Jupyter_files/shallow_models_online/cic_test_sample_binary.csv")

# %%
cicdataset = cicdataset.sample(frac=0.1)
cicdataset.reset_index(drop=True, inplace=True)
cicdataset.head()
# Out:
#    Destination Port  Flow Duration  Total Fwd Packets  Total Backward Packets  \
# 0                53            211                  2                       2
# 1             60023             67                  1                       1
# 2                53          77745                  1                       1
# 3               443       51895355                 24                      18
# 4                80      115930178                 17                      15
#
#    Total Length of Fwd Packets  Total Length of Bwd Packets  \
# 0                           62                          164
# 1                            6                            6
# 2                           57                          185
# 3                         1518                        17698
# 4                         1090                         1356
#
#    Fwd Packet Length Max  Fwd Packet Length Min  Fwd Packet Length Mean  \
# 0                     31                     31               31.000000
# 1                      6                      6                6.000000
# 2                     57                     57               57.000000
# 3                    677                      0               63.250000
# 4                   1090                      0               64.117647
#
#    Fwd Packet Length Std  ...  min_seg_size_forward   Active Mean  \
# 0               0.000000  ...                    20       0.00000
# 1               0.000000  ...                    20       0.00000
# 2               0.000000  ...                    20       0.00000
# 3             158.787320  ...                    32  706511.00000
# 4             264.363831  ...                    32   19202.90909
#
#     Active Std  Active Max  Active Min   Idle Mean     Idle Std  Idle Max  \
# 0      0.00000           0           0         0.0      0.00000         0
# 1      0.00000           0           0         0.0      0.00000         0
# 2      0.00000           0           0         0.0      0.00000         0
# 3      0.00000      706511      706511  51200000.0      0.00000  51200000
# 4  11423.99701       53317       14951  10200000.0  53830.13802  10200000
#
#    Idle Min   Label
# 0         0  BENIGN
# 1         0  BENIGN
# 2         0  BENIGN
# 3  51200000  BENIGN
# 4  10000000  BENIGN
#
# [5 rows x 79 columns]

# %%
# Define the discriminator model
import torch
from torch import nn


class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(data_dim, 40),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(40, 32),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(32, 16),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(16, 8),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(8, 1),
            nn.Sigmoid()
        )

    def forward(self, data):
        validity = self.model(data)
        return validity

# %%
# save all the different network configurations
import glob

discr_models_lst = glob.glob('./models/discr_model*.pth')
print(discr_models_lst)
# Out:
# ['./models\\discr_model-lr=0.0002-batch=64-epochs=0.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=1.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=10.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=11.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=12.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=13.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=14.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=15.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=16.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=17.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=18.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=19.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=2.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=20.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=21.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=22.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=23.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=24.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=25.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=26.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=27.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=28.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=29.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=3.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=30.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=31.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=32.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=33.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=34.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=35.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=36.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=37.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=38.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=39.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=4.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=40.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=41.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=42.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=43.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=44.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=45.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=46.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=47.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=48.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=49.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=5.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=50.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=51.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=52.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=53.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=54.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=55.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=56.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=57.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=58.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=59.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=6.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=60.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=61.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=62.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=63.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=64.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=65.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=66.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=67.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=68.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=69.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=7.pth', './models\\discr_model-lr=0.0002-batch=64-epochs=70.pth', './mo ...

# %%
discr_models_lst[0][9:-3]
# Out:
# 'discr_model-lr=0.0002-batch=64-epochs=0.'

# %%
data_dim = 47
discriminator = Discriminator()

# %%
selected_features = ['Destination Port', 'Total Fwd Packets', 'Total Backward Packets', 'Total Length of Fwd Packets',
                     'Total Length of Bwd Packets', 'Fwd Packet Length Max', 'Fwd Packet Length Min', 'Fwd Packet Length Mean',
                     'Fwd Packet Length Std', 'Bwd Packet Length Max', 'Bwd Packet Length Min', 'Bwd Packet Length Mean', 
                     'Bwd Packet Length Std', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max',
                     'Flow IAT Min', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Mean', 'Bwd IAT Std',
                     'Bwd IAT Max', 'Bwd IAT Min', 'Min Packet Length', 'Max Packet Length', 
                     'Packet Length Mean', 'Packet Length Std', 'FIN Flag Count', 'SYN Flag Count', 'RST Flag Count', 
                     'PSH Flag Count', 'ACK Flag Count', 'URG Flag Count', 'CWE Flag Count', 'ECE Flag Count']

added_features = ['Fwd PSH Flags', 'Fwd URG Flags', 'Bwd PSH Flags', 'Bwd URG Flags']

#extra_features = ['Active Max', 'Idle Max' ]

computed_features = ['Flow Duration', 'Flow Bytes/s', 'Flow Packets/s', 'Fwd Packets/s', 'Bwd Packets/s', 'Packet Length Variance']

selected_features_total = (selected_features + 
                           added_features + 
                           computed_features)

# %%
print(cicdataset.columns)
# Out:
# Index(['Destination Port', 'Flow Duration', 'Total Fwd Packets',
#        'Total Backward Packets', 'Total Length of Fwd Packets',
#        'Total Length of Bwd Packets', 'Fwd Packet Length Max',
#        'Fwd Packet Length Min', 'Fwd Packet Length Mean',
#        'Fwd Packet Length Std', 'Bwd Packet Length Max',
#        'Bwd Packet Length Min', 'Bwd Packet Length Mean',
#        'Bwd Packet Length Std', 'Flow Bytes/s', 'Flow Packets/s',
#        'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min',
#        'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max',
#        'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean', 'Bwd IAT Std',
#        'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags', 'Bwd PSH Flags',
#        'Fwd URG Flags', 'Bwd URG Flags', 'Fwd Header Length',
#        'Bwd Header Length', 'Fwd Packets/s', 'Bwd Packets/s',
#        'Min Packet Length', 'Max Packet Length', 'Packet Length Mean',
#        'Packet Length Std', 'Packet Length Variance', 'FIN Flag Count',
#        'SYN Flag Count', 'RST Flag Count', 'PSH Flag Count', 'ACK Flag Count',
#        'URG Flag Count', 'CWE Flag Count', 'ECE Flag Count', 'Down/Up Ratio',
#        'Average Packet Size', 'Avg Fwd Segment Size', 'Avg Bwd Segment Size',
#        'Fwd Header Length.1', 'Fwd Avg Bytes/Bulk', 'Fwd Avg Packets/Bulk',
#        'Fwd Avg Bulk Rate', 'Bwd Avg Bytes/Bulk', 'Bwd Avg Packets/Bulk',
#        'Bwd Avg Bulk Rate', 'Subflow Fwd Packets', 'Subflow Fwd Bytes',
#        'Subflow Bwd Packets', 'Subflow Bwd Bytes', 'Init_Win_bytes_forward',
#        'Init_Win_bytes_backward', 'act_data_pkt_fwd', 'min_seg_size_forward',
#        'Active Mean', 'Active Std', 'Active Max', 'Active Min', 'Idle Mean',
#        'Idle Std', 'Idle Max', 'Idle Min', 'Label'],
#       dtype='object')

# %%
minmaxscaler = joblib.load('minmaxscaler')

# %%
simp = SimpleImputer(keep_empty_features=True)

cicdataset_labels = cicdataset['Label']

cicdataset = cicdataset[selected_features_total]

cicdataset.replace([np.inf, -np.inf], np.nan, inplace=True)

cicdataset_features = simp.fit_transform(cicdataset)

cicdataset_features = minmaxscaler.transform(cicdataset_features)

# %%
num_samples = len(cicdataset_features)
total_benign_conn = cicdataset_labels.value_counts().BENIGN
total_attack_conn = cicdataset_labels.value_counts().ATTACK
best_accuracy = -1
best_pair = {}

for PATH_discr in discr_models_lst:
    discriminator.load_state_dict(torch.load(PATH_discr))
    discriminator.eval()
    true_positive = 0
    true_negative = 0
    false_positive = 0
    false_negative = 0
    for i in range(len(cicdataset_features)):
        row_label = cicdataset_labels[i]
        row_features = cicdataset_features[i]
        row_features = torch.tensor(row_features).float()
        model_output = discriminator(row_features)
        if model_output < 0.5:
            attack = True
        else:
            attack = False
        if (row_label == 'BENIGN' and attack == False):
            true_negative += 1
        if (row_label == 'ATTACK' and attack == True):
            true_positive += 1
        if (row_label == 'BENIGN' and attack == True):
            false_positive += 1
        if (row_label == 'ATTACK' and attack == False):
            false_negative += 1
    
    benign_recall = true_negative / (true_negative + false_positive)
    attack_recall = true_positive / (true_positive + false_negative)
    
    benign_precision = true_negative / (true_negative + false_negative)
    attack_precision = true_positive / (true_positive + false_positive)
    
    benign_f1 = 2 * (benign_recall * benign_precision) / (benign_recall + benign_precision)
    attack_f1 = 2 * (attack_recall * attack_precision) / (attack_recall + attack_precision)
    
    accuracy = (true_positive + true_negative) / (true_positive + true_negative + false_positive + false_negative)
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_pair  = {PATH_discr : accuracy}
    
    data = {
        "BENIGN": {"Precision": benign_precision, "Recall": benign_recall, "F1-Score": benign_f1},
        "ATTACK": {"Precision": attack_precision, "Recall": attack_recall, "F1-Score": attack_f1}
    }
    
    # Convert the dictionary to a list of lists
    table = [[row_name] + list(row_data.values()) for row_name, row_data in data.items()]
    # Get the column names
    #column_names = [""] + list(data.values()[0].keys())
    column_names = ["Precision", "Recall", "F1-Score"]
    # Print the table using tabulate
    #print(tabulate(table, headers=column_names, tablefmt="fancy_grid"))
    
    str1 = 'Results of ' + str(PATH_discr) + ' ...'
    str2 = "Overall Accuracy: " + str(accuracy)
    str3 = tabulate(table, headers=column_names, tablefmt="fancy_grid")
    output = str1 + "\n" + str2 + "\n" + str3 + "\n" + "###################################################"
    print(output)
    
    output2 = str2 + "\n" + str(data)
    file_name = './test_eval2/' + 'output-' + PATH_discr[9:-3] + 'txt'
    file = open(file_name, 'w')
    a = file.write(output2)
    file.close()

print("Best model overall is: " + str(best_pair))
# Out:
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=0.pth ...
# Overall Accuracy: 0.9341858904157982
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.954437 │ 0.964279 │   0.959333 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.84595  │ 0.809929 │   0.827548 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=1.pth ...
# Overall Accuracy: 0.9362701805207193
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.971042 │ 0.94914  │   0.959966 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.80789  │ 0.883131 │   0.843837 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=10.pth ...
# Overall Accuracy: 0.9591973716748508
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.971698 │ 0.977795 │   0.974737 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.905878 │ 0.882406 │   0.893988 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=11.pth ...
# Overall Accuracy: 0.9546755219557
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.970014 │ 0.973802 │   0.971904 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.890055 │ 0.875702 │   0.88282  │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=12.pth ...
# Overall Accuracy: 0.9635425866393471
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.97271  │ 0.982271 │   0.977467 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.923702 │ 0.886211 │   0.904568 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=13.pth ...
# Overall Accuracy: 0.9646023951672731
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.974972 │ 0.981218 │   0.978085 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.920342 │ 0.895996 │   0.908006 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=14.pth ...
# Overall Accuracy: 0.9647437029709965
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0
│
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.913778 │ 0.969741 │   0.940928 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=59.pth ...
# Overall Accuracy: 0.9784505599321722
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.994956 │ 0.97819  │   0.986502 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.915806 │ 0.979525 │   0.946594 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=6.pth ...
# Overall Accuracy: 0.9516020772247147
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.972637 │ 0.967088 │   0.969854 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.867233 │ 0.887661 │   0.877328 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=60.pth ...
# Overall Accuracy: 0.9767548662874908
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.994636 │ 0.976391 │   0.985429 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.909382 │ 0.978257 │   0.942563 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=61.pth ...
# Overall Accuracy: 0.9734341328999894
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.984393 │ 0.982579 │   0.983485 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.92861  │ 0.935677 │   0.93213  │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=62.pth ...
# Overall Accuracy: 0.9729395555869573
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.995545 │ 0.97073  │   0.982981 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.890422 │ 0.982062 │   0.934    │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=63.pth ...
# Overall Accuracy: 0.9789804641961353
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.993463 │ 0.980341 │   0.986858 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.923024 │ 0.973365 │   0.947526 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=64.pth ...
# Overall Accuracy: 0.9718090931571696
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.981772 │ 0.983237 │   0.982504 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.930356 │ 0.924624 │   0.927481 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=65.pth ...
# Overall Accuracy: 0.9747059031335006
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.983865 │ 0.984729 │   0.984297 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.936716 │ 0.933321 │   0.935015 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=66.pth ...
# Overall Accuracy: 0.9768961740912142
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.989041 │ 0.982184 │   0.9856   │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.928483 │ 0.955064 │   0.941586 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=67.pth ...
# Overall Accuracy: 0.9780972904228636
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.993017 │ 0.979682 │   0.986304 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.920515 │ 0.971553 │   0.945346 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=68.pth ...
# Overall Accuracy: 0.973010209488819
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.992883 │ 0.973451 │   0.983071 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.898575 │ 0.97119  │   0.933473 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=69.pth ...
# Overall Accuracy: 0.9753064612993253
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.984514 │ 0.984817 │   0.984665 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.937228 │ 0.936039 │   0.936633 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=7.pth ...
# Overall Accuracy: 0.9517080580775074
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.971807 │ 0.968097 │   0.969949 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.870318 │ 0.884037 │   0.877124 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=70.pth ...
# Overall Accuracy: 0.9784505599321722
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.992801 │ 0.980341 │   0.986531 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.922825 │ 0.970647 │   0.946132 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=71.pth ...
# Overall Accuracy: 0.971950400960893
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.992256 │ 0.972749 │   0.982406 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.895928 │ 0.968654 │   0.930872 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=72.pth ...
# Overall Accuracy: 0.9704666690217967
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.992462 │ 0.970686 │   0.981454 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.889018 │ 0.96956  │   0.927544 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=73.pth ...
# Overall Accuracy: 0.9708905924329672
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.992378 │ 0.971301 │   0.981726 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.891054 │ 0.969197 │   0.928485 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=74.pth ...
# Overall Accuracy: 0.9705019959727276
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.98361  │ 0.979682 │   0.981642 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.917469 │ 0.932596 │   0.924971 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=75.pth ...
# Overall Accuracy: 0.9731868442434733
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.990777 │ 0.975777 │   0.983219 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.905866 │ 0.962493 │   0.933322 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=76.pth ...
# Overall Accuracy: 0.9716677853534461
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.982318 │ 0.982491 │   0.982405 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.927652 │ 0.92698  │   0.927316 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=77.pth ...
# Overall Accuracy: 0.9713498427950683
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.981382 │ 0.983061 │   0.982221 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.929562 │ 0.922993 │   0.926266 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=78.pth ...
# Overall Accuracy: 0.9696541491503868
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.978569 │ 0.983851 │   0.981203 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.931801 │ 0.911035 │   0.921301 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=79.pth ...
# Overall Accuracy: 0.9728335747341647
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.984509 │ 0.981701 │   0.983103 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.925322 │ 0.93622  │   0.930739 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=8.pth ...
# Overall Accuracy: 0.9593033525276433
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.973643 │ 0.975864 │   0.974752 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.899396 │ 0.890922 │   0.895139 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=80.pth ...
# Overall Accuracy: 0.9714911505987918
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.983886 │ 0.980648 │   0.982264 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.921166 │ 0.933684 │   0.927382 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=81.pth ...
# Overall Accuracy: 0.973010209488819
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.990338 │ 0.975996 │   0.983115 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.90648  │ 0.960681 │   0.932794 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=82.pth ...
# Overall Accuracy: 0.9751651534956018
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.992375 │ 0.976654 │   0.984452 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.909524 │ 0.969016 │   0.938328 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=83.pth ...
# Overall Accuracy: 0.9749885187409475
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.989318 │ 0.979507 │   0.984388 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.918712 │ 0.956333 │   0.937145 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=84.pth ...
# Overall Accuracy: 0.9726569399795104
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.983102 │ 0.98293  │   0.983016 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.929567 │ 0.930241 │   0.929904 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=85.pth ...
# Overall Accuracy: 0.9746705761825697
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.993692 │ 0.974724 │   0.984116 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.903258 │ 0.974452 │   0.937505 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=86.pth ...
# Overall Accuracy: 0.9747765570353623
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.993075 │ 0.97547  │   0.984194 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.905622 │ 0.971915 │   0.937598 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=87.pth ...
# Overall Accuracy: 0.9646730490691349
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.995542 │ 0.960418 │   0.977665 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.857346 │ 0.982243 │   0.915555 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=88.pth ...
# Overall Accuracy: 0.976436923729113
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.992563 │ 0.978059 │   0.985257 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.914559 │ 0.969741 │   0.941342 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=89.pth ...
# Overall Accuracy: 0.9740346910658141
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.992672 │ 0.974943 │   0.983728 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.903645 │ 0.970284 │   0.93578  │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=9.pth ...
# Overall Accuracy: 0.9445366870385417
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.955517 │ 0.976567 │   0.965927 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.893562 │ 0.812285 │   0.850987 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=90.pth ...
# Overall Accuracy: 0.9750238456918784
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.993916 │ 0.974943 │   0.984338 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.904098 │ 0.975358 │   0.938377 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=91.pth ...
# Overall Accuracy: 0.9767548662874908
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.991036 │ 0.979989 │   0.985482 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.921012 │ 0.963399 │   0.941729 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=92.pth ...
# Overall Accuracy: 0.9721976896174092
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.9839   │ 0.981525 │   0.982711 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.924471 │ 0.933684 │   0.929054 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=93.pth ...
# Overall Accuracy: 0.9731515172925425
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.984771 │ 0.981833 │   0.9833   │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.925899 │ 0.937307 │   0.931569 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=94.pth ...
# Overall Accuracy: 0.9747765570353623
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.994047 │ 0.974504 │   0.984178 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.902631 │ 0.975901 │   0.937837 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=95.pth ...
# Overall Accuracy: 0.9768255201893524
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.991429 │ 0.979682 │   0.985521 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.920021 │ 0.96503  │   0.941988 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=96.pth ...
# Overall Accuracy: 0.9776380400607624
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.992574 │ 0.979551 │   0.986019 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.919904 │ 0.969741 │   0.944165 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=97.pth ...
# Overall Accuracy: 0.9689829370827004
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.996105 │ 0.965245 │   0.980432 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.872771 │ 0.984417 │   0.925238 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=98.pth ...
# Overall Accuracy: 0.9737520754583672
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.983676 │ 0.98372  │   0.983698 │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.932765 │ 0.932596 │   0.932681 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Results of ./models\discr_model-lr=0.0002-batch=64-epochs=99.pth ...
# Overall Accuracy: 0.9767548662874908
# ╒════════╤═════════════╤══════════╤════════════╕
# │        │   Precision │   Recall │   F1-Score │
# ╞════════╪═════════════╪══════════╪════════════╡
# │ BENIGN │    0.994591 │ 0.976435 │   0.98543  │
# ├────────┼─────────────┼──────────┼────────────┤
# │ ATTACK │    0.90952  │ 0.978076 │   0.942553 │
# ╘════════╧═════════════╧══════════╧════════════╛
# ###################################################
# Best model overall is: {'./models\\discr_model-lr=0.0002-batch=64-epochs=63.pth': 0.9789804641961353}
