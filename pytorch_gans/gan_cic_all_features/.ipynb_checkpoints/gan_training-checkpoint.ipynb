# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets, transforms
from torchvision.utils import make_grid
from tqdm import tqdm
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer
import torch.optim as optim
from torch.autograd import Variable
from torch import FloatTensor, LongTensor
import joblib

# %%
# selected_features = ['Destination Port', 'Total Fwd Packets', 'Total Backward Packets', 'Total Length of Fwd Packets',
#                      'Total Length of Bwd Packets', 'Fwd Packet Length Max', 'Fwd Packet Length Min', 'Fwd Packet Length Mean',
#                      'Fwd Packet Length Std', 'Bwd Packet Length Max', 'Bwd Packet Length Min', 'Bwd Packet Length Mean', 
#                      'Bwd Packet Length Std', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max',
#                      'Flow IAT Min', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Mean', 'Bwd IAT Std',
#                      'Bwd IAT Max', 'Bwd IAT Min', 'Min Packet Length', 'Max Packet Length', 
#                      'Packet Length Mean', 'Packet Length Std', 'FIN Flag Count', 'SYN Flag Count', 'RST Flag Count', 
#                      'PSH Flag Count', 'ACK Flag Count', 'URG Flag Count', 'CWE Flag Count', 'ECE Flag Count']

# added_features = ['Fwd PSH Flags', 'Fwd URG Flags', 'Bwd PSH Flags', 'Bwd URG Flags']

# #extra_features = ['Active Max', 'Idle Max' ]

# computed_features = ['Flow Duration', 'Flow Bytes/s', 'Flow Packets/s', 'Fwd Packets/s', 'Bwd Packets/s', 'Packet Length Variance']

# selected_features_total = (selected_features + 
#                            added_features + 
#                            computed_features)

# %%
class PreProcessor:
    def __init__(self, file_path):
        self.input_dataset = pd.read_csv(file_path)
        #self.selected_features = selected_features
        
    def print_input_data(self):
        print('The input dataset has the following columns/features')
        print(self.input_dataset.columns)
        labels = self.input_dataset['Label']
        print('The labels are as follows')
        print(labels.value_counts())
        print(labels.value_counts().plot.pie())
        
    def preprocess(self):
        X, y = self.feature_selection()
        X = self.imputing(X)
        X = self.scaling(X)
        y = self.label_binarization(y)
        self.data = torch.tensor(X)
        self.targets = torch.tensor(y)
        
    def feature_selection(self):
        #X = self.input_dataset[self.selected_features]
        X = self.input_dataset.iloc[:, :-1]
        y = self.input_dataset['Label']
        return X, y
    
    def imputing(self, X):
        X.replace([np.inf, -np.inf], np.nan, inplace=True)
        Imp = SimpleImputer()
        X = Imp.fit_transform(X)
        return X
        
    def scaling(self, X):
        scaler = preprocessing.MinMaxScaler()
        X = scaler.fit_transform(X)
        joblib.dump(scaler, 'minmaxscaler')
        return X
    
    def label_binarization(self, y):
        for label in y:
            if (label != 'BENIGN' and label != 'ATTACK'):
                y.replace(label, 'ATTACK', inplace=True)
        y.replace('BENIGN', 1, inplace=True)
        y.replace('ATTACK', 0, inplace=True)
        return y
    
    def return_data(self):
        return self.data, self.targets

# %%
class MyDataset(Dataset):
    def __init__(self, file_path):
        preprocessor = PreProcessor(file_path)
        preprocessor.print_input_data()
        preprocessor.preprocess()
        self.data, self.targets = preprocessor.return_data()
        
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        row = self.data[idx]
        label = self.targets[idx]
        return row, label

# %%
num_epochs = 100

# %%
sample_path = "C:/Users/katsa/OneDrive/Jupyter_files/shallow_models_online/cic_train_sample_binary.csv"
CICDataset = MyDataset(sample_path)
batch_size = 64
dataloader = DataLoader(CICDataset, batch_size=batch_size, 
                          shuffle=True, drop_last=True)
# Out:
# The input dataset has the following columns/features
# Index(['Destination Port', 'Flow Duration', 'Total Fwd Packets',
#        'Total Backward Packets', 'Total Length of Fwd Packets',
#        'Total Length of Bwd Packets', 'Fwd Packet Length Max',
#        'Fwd Packet Length Min', 'Fwd Packet Length Mean',
#        'Fwd Packet Length Std', 'Bwd Packet Length Max',
#        'Bwd Packet Length Min', 'Bwd Packet Length Mean',
#        'Bwd Packet Length Std', 'Flow Bytes/s', 'Flow Packets/s',
#        'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min',
#        'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max',
#        'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean', 'Bwd IAT Std',
#        'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags', 'Bwd PSH Flags',
#        'Fwd URG Flags', 'Bwd URG Flags', 'Fwd Header Length',
#        'Bwd Header Length', 'Fwd Packets/s', 'Bwd Packets/s',
#        'Min Packet Length', 'Max Packet Length', 'Packet Length Mean',
#        'Packet Length Std', 'Packet Length Variance', 'FIN Flag Count',
#        'SYN Flag Count', 'RST Flag Count', 'PSH Flag Count', 'ACK Flag Count',
#        'URG Flag Count', 'CWE Flag Count', 'ECE Flag Count', 'Down/Up Ratio',
#        'Average Packet Size', 'Avg Fwd Segment Size', 'Avg Bwd Segment Size',
#        'Fwd Header Length.1', 'Fwd Avg Bytes/Bulk', 'Fwd Avg Packets/Bulk',
#        'Fwd Avg Bulk Rate', 'Bwd Avg Bytes/Bulk', 'Bwd Avg Packets/Bulk',
#        'Bwd Avg Bulk Rate', 'Subflow Fwd Packets', 'Subflow Fwd Bytes',
#        'Subflow Bwd Packets', 'Subflow Bwd Bytes', 'Init_Win_bytes_forward',
#        'Init_Win_bytes_backward', 'act_data_pkt_fwd', 'min_seg_size_forward',
#        'Active Mean', 'Active Std', 'Active Max', 'Active Min', 'Idle Mean',
#        'Idle Std', 'Idle Max', 'Idle Min', 'Label'],
#       dtype='object')
# The labels are as follows
# BENIGN    113747
# ATTACK     27790
# Name: Label, dtype: int64
# Axes(0.22375,0.11;0.5775x0.77)

# %%
# Define the generator model

class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(latent_dim + 1, 16),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(16, 24),
            nn.BatchNorm1d(24, 0.8),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(24, 32),
            nn.BatchNorm1d(32, 0.8),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(32, 40),
            nn.BatchNorm1d(40, 0.8),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(40, data_dim),
            nn.Sigmoid()
        )

    def forward(self, z, label):
        label = torch.full((batch_size, 1), label)
        z = torch.cat((noise, label), 1)
        data = self.model(z)
        return data

# %%
# Define the discriminator model

class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(data_dim, 40),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(40, 32),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(32, 16),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(16, 8),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(8, 1),
            nn.Sigmoid()
        )

    def forward(self, data):
        validity = self.model(data)
        return validity

# %%
# Definition of hyperparameters

#data_dim=len(CICDataset.input_dataset.columns)
data_dim=78
latent_dim = 8
print(data_dim)
lr = 0.0002
adversarial_loss = nn.BCELoss()
generator = Generator()
discriminator = Discriminator()
optimizer_G = optim.Adam(generator.parameters(), lr=lr, betas=(0.5, 0.999))
optimizer_D = optim.Adam(discriminator.parameters(), lr=lr, betas=(0.5, 0.999))
# Out:
# 78

# %%
noise = torch.randn(batch_size, latent_dim)

# %%
epochs_lst = [5, 10, 15, 20, 25, 30]

# %%
for epoch in range(num_epochs):
    for i, (data, labels) in enumerate(dataloader):
        batch_size = data.shape[0]
        real_data = Variable(data.type(FloatTensor))        
        labels = Variable(labels.float())
        labels = labels.view(-1, 1).type(FloatTensor)
        
        # Train the discriminator
        optimizer_D.zero_grad()
        d_real_outputs = discriminator(real_data)
        d_real_loss = adversarial_loss(d_real_outputs, labels)
        
        fake_data = generator(noise, 0)
        d_fake_outputs = discriminator(fake_data.detach())
        d_fake_loss1 = adversarial_loss(d_fake_outputs, torch.full((batch_size, 1), 0.4).type(FloatTensor))
        
        fake_data = generator(noise, 1)
        d_fake_outputs = discriminator(fake_data.detach())
        d_fake_loss2 = adversarial_loss(d_fake_outputs, torch.full((batch_size, 1), 0.6).type(FloatTensor))
        
        d_loss = d_real_loss + d_fake_loss1 + d_fake_loss2
        d_loss.backward()
        optimizer_D.step()
        
        # Train the generator
        optimizer_G.zero_grad()
        noise = torch.randn(batch_size, latent_dim)
        fake_data = generator(noise, 0)
        d_fake_outputs = discriminator(fake_data)
        targets = torch.full((batch_size, 1), 0)
        g_loss1 = adversarial_loss(d_fake_outputs, targets.float())

        noise = torch.randn(batch_size, latent_dim)
        fake_data = generator(noise, 1)
        d_fake_outputs = discriminator(fake_data)
        targets = torch.full((batch_size, 1), 1)
        g_loss2 = adversarial_loss(d_fake_outputs, targets.float())
        
        g_loss = g_loss1 + g_loss2
        g_loss.backward()
        optimizer_G.step()
        

        # Print the loss for each epoch
        if i % 1000 == 0:
            print("[Epoch %d/%d] [Batch %d/%d] [D loss: %f] [G loss: %f]" % (epoch, num_epochs, i, len(dataloader), d_loss.item(), g_loss.item()))

    print('Saving models...')
    # save discriminator model used for classification
    PATH_disc = './models/discr_model-'
    PATH = PATH_disc + 'lr=' + str(lr) + '-batch=' + str(batch_size) + '-epochs=' + str(epoch) + '.pth'
    torch.save(discriminator.state_dict(), PATH)
    
    # save generator model
    PATH_gen = './models/gen_model-'
    PATH = PATH_gen + 'lr=' + str(lr) + '-batch=' + str(batch_size) + '-epochs=' + str(epoch) + '.pth'
    torch.save(generator.state_dict(), PATH)
# Out:
# [Epoch 0/100] [Batch 0/2211] [D loss: 2.043547] [G loss: 1.391188]
# [Epoch 0/100] [Batch 1000/2211] [D loss: 1.608773] [G loss: 1.065721]
# [Epoch 0/100] [Batch 2000/2211] [D loss: 1.579800] [G loss: 0.905251]
# Saving models...
# [Epoch 1/100] [Batch 0/2211] [D loss: 1.690504] [G loss: 0.887115]
# [Epoch 1/100] [Batch 1000/2211] [D loss: 1.665305] [G loss: 0.848333]
# [Epoch 1/100] [Batch 2000/2211] [D loss: 1.719853] [G loss: 0.822925]
# Saving models...
# [Epoch 2/100] [Batch 0/2211] [D loss: 1.689143] [G loss: 0.833569]
# [Epoch 2/100] [Batch 1000/2211] [D loss: 1.635157] [G loss: 0.823887]
# [Epoch 2/100] [Batch 2000/2211] [D loss: 1.606047] [G loss: 0.834144]
# Saving models...
# [Epoch 3/100] [Batch 0/2211] [D loss: 1.662547] [G loss: 0.840933]
# [Epoch 3/100] [Batch 1000/2211] [D loss: 1.625373] [G loss: 0.834637]
# [Epoch 3/100] [Batch 2000/2211] [D loss: 1.728610] [G loss: 0.843776]
# Saving models...
# [Epoch 4/100] [Batch 0/2211] [D loss: 1.746937] [G loss: 0.786991]
# [Epoch 4/100] [Batch 1000/2211] [D loss: 1.568103] [G loss: 0.848212]
# [Epoch 4/100] [Batch 2000/2211] [D loss: 1.590467] [G loss: 0.859591]
# Saving models...
# [Epoch 5/100] [Batch 0/2211] [D loss: 1.699057] [G loss: 0.835363]
# [Epoch 5/100] [Batch 1000/2211] [D loss: 1.602891] [G loss: 0.761582]
# [Epoch 5/100] [Batch 2000/2211] [D loss: 1.708753] [G loss: 0.830955]
# Saving models...
# [Epoch 6/100] [Batch 0/2211] [D loss: 1.652937] [G loss: 0.803330]
# [Epoch 6/100] [Batch 1000/2211] [D loss: 1.597888] [G loss: 0.856216]
# [Epoch 6/100] [Batch 2000/2211] [D loss: 1.683596] [G loss: 0.768234]
# Saving models...
# [Epoch 7/100] [Batch 0/2211] [D loss: 1.651190] [G loss: 0.743401]
# [Epoch 7/100] [Batch 1000/2211] [D loss: 1.729238] [G loss: 0.833501]
# [Epoch 7/100] [Batch 2000/2211] [D loss: 1.699802] [G loss: 0.769647]
# Saving models...
# [Epoch 8/100] [Batch 0/2211] [D loss: 1.635937] [G loss: 0.820004]
# [Epoch 8/100] [Batch 1000/2211] [D loss: 1.585686] [G loss: 0.835778]
# [Epoch 8/100] [Batch 2000/2211] [D loss: 1.592074] [G loss: 0.894847]
# Saving models...
# [Epoch 9/100] [Batch 0/2211] [D loss: 1.665957] [G loss: 0.800295]
# [Epoch 9/100] [Batch 1000/2211] [D loss: 1.609036] [G loss: 0.821865]
# [Epoch 9/100] [Batch 2000/2211] [D loss: 1.689000] [G loss: 0.845237]
# Saving models...
# [Epoch 10/100] [Batch 0/2211] [D loss: 1.624112] [G loss: 0.789507]
# [Epoch 10/100] [Batch 1000/2211] [D loss: 1.582772] [G loss: 0.872981]
# [Epoch 10/100] [Batch 2000/2211] [D loss: 1.727196] [G loss: 0.777117]
# Saving models...
# [Epoch 11/100] [Batch 0/2211] [D loss: 1.682804] [G loss: 0.764560]
# [Epoch 11/100] [Batch 1000/2211] [D loss: 1.614887] [G loss: 0.772635]
# [Epoch 11/100] [Batch 2000/2211] [D loss: 1.643929] [G loss: 0.876889]
# Saving models...
# [Epoch 12/100] [Batch 0/2211] [D loss: 1.630113] [G loss: 0.852387]
# [Epoch 12/100] [Batch 1000/2211] [D loss: 1.800829] [G loss: 0.856955]
# [Epoch 12/100] [Batch 2000/2211] [D loss: 1.668164] [G loss: 0.851830]
# Saving models...
# [Epoch 13/100] [Batch 0/2211] [D loss: 1.679130] [G loss: 0.788681]
# [Epoch 13/100] [Batch 1000/2211] [D loss: 1.696985] [G loss: 0.813731]
# [Epoch 13/100] [Batch 2000/2211] [D loss: 1.623687] [G loss: 0.770645]
# Saving models...
# [Epoch 14/100] [Batch 0/2211] [D loss: 1.679877] [G loss: 0.765630]
# [Epoch 14/100] [Batch 1000/2211] [D loss: 1.684788] [G loss: 0.906046]
# [Epoch 14/100] [Batch 2000/2211] [D loss: 1.676197] [G loss: 0.755627]
# Saving models...
# [Epoch 15/100] [Batch 0/2211] [D loss: 1.556092] [G loss: 0.816901]
# [Epoch 15/100] [Batch 1000/2211] [D loss: 1.749731] [G loss: 0.817942]
# [Epoch 15/100] [Batch 2000/2211] [D loss: 1.622659] [G loss: 0.847794]
# Saving models...
# [Epoch 16/100] [Batch 0/2211] [D loss: 1.691287] [G loss: 0.784207]
# [Epoch 16/100] [Batch 1000/2211] [D loss: 1.627255] [G loss: 0.785094]
# [Epoch 16/100] [Batch 2000/2211] [D loss: 1.665052] [G loss: 0.800261]
# Saving models...
# [Epoch 17/100] [Batch 0/2211] [D loss: 1.640060] [G loss: 0.833708]
# [Epoch 17/100] [Batch 1000/2211] [D loss: 1.641825] [G loss: 0.828646]
# [Epoch 17/100] [Batch 2000/2211] [D loss: 1.668376] [G loss: 0.852380]
# Saving models...
# [Epoch 18/100] [Batch 0/2211] [D loss: 1.576806] [G loss: 0.834615]
# [Epoch 18/100] [Batch 1000/2211] [D loss: 1.645297] [G loss: 0.817788]
# [Epoch 18/100] [Batch 2000/2211] [D loss: 1.538909] [G loss: 0.840277]
# Saving models...
# [Epoch 19/100] [Batch 0/2211] [D loss: 1.583911] [G loss: 0.814423]
# [Epoch 19/100] [Batch 1000/2211] [D loss: 1.626823] [G loss: 0.834125]
# [Epoch 19/100] [Batch 2000/2211] [D loss: 1.659499] [G loss: 0.821949]
# Saving models...
# [Epoch 20/100] [Batch 0/2211] [D loss: 1.636403] [G loss: 0.771258]
# [Epoch 20/100] [Batch 1000/2211] [D loss: 1.684732] [G loss: 0.777966]
# [Epoch 20/100] [Batch 2000/2211] [D loss: 1.646379] [G loss: 0.809175]
# Saving models...
# [Epoch 21/100] [Batch 0/2211] [D loss: 1.622605] [G loss: 0.787600]
# [Epoch 21/100] [Batch 1000/2211] [D loss: 1.602563] [G loss: 0.769534]
# [Epoch 21/100] [Batch 2000/2211] [D loss: 1.651018] [G loss: 0.827279]
# Saving models...
# [Epoch 22/100] [Batch 0/2211] [D loss: 1.592400] [G loss: 0.797779]
# [Epoch 22/100] [Batch 1000/2211] [D loss: 1.618297] [G loss: 0.790185]
# [Epoch 22/100] [Batch 2000/2211] [D loss: 1.630191] [G loss: 0.820873]
# Saving models...
# [Epoch 23/100] [Batch 0/2211] [D loss: 1.614221] [G loss: 0.834091]
# [Epoch 23/100] [Batch 1000/2211] [D loss: 1.642576] [G loss: 0.815947]
# [Epoch 23/100] [Batch 2000/2211] [D loss: 1.589856] [G loss: 0.828931]
# Saving models...
# [Epoch 24/100] [Batch 0/2211] [D loss: 1.603119] [G loss: 0.804362]
# [Epoch 24/100] [Batch 1000/2211] [D loss: 1.581815] [G loss: 0.818364]
# [Epoch 24/100] [Batch 2000/2211] [D loss: 1.559937] [G loss: 0.842529]
# Saving models...
# [Epoch 25/100] [Batch 0/2211] [D loss: 1.645756] [G loss: 0.818238]
# [Epoch 25/100] [Batch 1000/2211] [D loss: 1.517750] [G loss: 0.867536]
# [Epoch 25/100] [Batch 2000/2211] [D loss: 1.622873] [G loss: 0.895472]
# Saving models...
# [Epoch 26/100] [Batch 0/2211] [D loss: 1.622778] [G loss: 0.859460]
# [Epoch 26/100] [Batch 1000/2211] [D loss: 1.573565] [G loss: 0.876978]
# [Epoch 26/100] [Batch 2000/2211] [D loss: 1.624897] [G loss: 0.870750]
# Saving models...
# [Epoch 27/100] [Batch 0/2211] [D loss: 1.616320] [G loss: 0.933666]
# [Epoch 27/100] [Batch 1000/2211] [D loss: 1.603778] [G loss: 0.773987]
# [Epoch 27/100] [Batch 2000/2211] [D loss: 1.626018] [G loss: 0.816164]
# Saving models...
# [Epoch 28/100] [Batch 0/2211] [D loss: 1.659093] [G loss: 0.872572]
# [Epoch 28/100] [Batch 1000/2211] [D loss: 1.603132] [G loss: 0.797020]
# [Epoch 28/100] [Batch 2000/2211] [D loss: 1.555125] [G loss: 0.793645]
# Saving models...
# [Epoch 29/100] [Batch 0/2211] [D loss: 1.554098] [G loss: 0.875040]
# [Epoch 29/100] [Batch 1000/2211] [D loss: 1.575901] [G loss: 0.818904]
# [Epoch 29/100] [Batch 2000/2211] [D loss: 1.587014] [G loss: 0.974895]
# Saving models...
# [Epoch 30/100] [Batch 0/2211] [D loss: 1.582246] [G loss: 0.911638]
# [Epoch 30/100] [Batch 1000/2211] [D loss: 1.692528] [G loss: 0.883592]
# [Epoch 30/100] [Batch 2000/2211] [D loss: 1.600230] [G loss: 0.840819]
# Saving models...
# [Epoch 31/100] [Batch 0/2211] [D loss: 1.673571] [G loss: 0.818880]
# [Epoch 31/100] [Batch 1000/2211] [D loss: 1.580300] [G loss: 0.840642]
# [Epoch 31/100] [Batch 2000/2211] [D loss: 1.564500] [G loss: 0.843979]
# Saving models...
# [Epoch 32/100] [Batch 0/2211] [D loss: 1.673381] [G loss: 0.849714]
# [Epoch 32/100] [Batch 1000/2211] [D loss: 1.590627] [G loss: 0.816048]
# [Epoch 32/100] [Batch 2000/2211] [D loss: 1.601616] [G loss: 0.811175]
# Saving models...
# [Epoch 33/100] [Batch 0/2211] [D loss: 1.604303] [G loss: 0.838350]
# [Epoch 33/100] [Batch 1000/2211] [D loss: 1.629184] [G loss: 0.904092]
# [Epoch 33/100] [Batch 2000/2211] [D loss: 1.586500] [G loss: 0.795786]
# Saving models...
# [Epoch 34/100] [Batch 0/2211] [D loss: 1.603549] [G loss: 0.896616]
# [Epoch 34/100] [Batch 1000/2211] [D loss: 1.497536] [G loss: 0.866296]
# [Epoch 34/100] [Batch 2000/2211] [D loss: 1.555668] [G loss: 0.856819]
# Saving models...
# [Epoch 35/100] [Batch 0/2211] [D loss: 1.599868] [G loss: 0.825725]
# [Epoch 35/100] [Batch 1000/2211] [D loss: 1.607356] [G loss: 0.865744]
# [Epoch 35/100] [Batch 2000/2211] [D loss: 1.570966] [G loss: 0.790112]
# Saving models...
# [Epoch 36/100] [Batch 0/2211] [D loss: 1.589428] [G loss: 0.854074]
# [Epoch 36/100] [Batch 1000/2211] [D loss: 1.596788] [G loss: 0.826548]
# [Epoch 36/100] [Batch 2000/2211] [D loss: 1.588922] [G loss: 0.789613]
# Saving models...
# [Epoch 37/100] [Batch 0/2211] [D loss: 1.577477] [G loss: 0.800550]
# [Epoch 37/100] [Batch 1000/2211] [D loss: 1.599564] [G loss: 0.879241]
# [Epoch 37/100] [Batch 2000/2211] [D loss: 1.637881] [G loss: 0.849143]
# Saving models...
# [Epoch 38/100] [Batch 0/2211] [D loss: 1.579939] [G loss: 0.794236]
# [Epoch 38/100] [Batch 1000/2211] [D loss: 1.583498] [G loss: 0.898805]
# [Epoch 38/100] [Batch 2000/2211] [D loss: 1.563540] [G loss: 0.879822]
# Saving models...
# [Epoch 39/100] [Batch 0/2211] [D loss: 1.615616] [G loss: 0.795112]
# [Epoch 39/100] [Batch 1000/2211] [D loss: 1.605988] [G loss: 0.856444]
# [Epoch 39/100] [Batch 2000/2211] [D loss: 1.594877] [G loss: 0.846645]
# Saving models...
# [Epoch 40/100] [Batch 0/2211] [D loss: 1.625289] [G loss: 0.879609]
# [Epoch 40/100] [Batch 1000/2211] [D loss: 1.599479] [G loss: 0.836973]
# [Epoch 40/100] [Batch 2000/2211] [D loss: 1.545497] [G loss: 0.876300]
# Saving models...
# [Epoch 41/100] [Batch 0/2211] [D loss: 1.540270] [G loss: 0.835533]
# [Epoch 41/100] [Batch 1000/2211] [D loss: 1.576806] [G loss: 0.843260]
# [Epoch 41/100] [Batch 2000/2211] [D loss: 1.587136] [G loss: 0.801256]
# Saving models...
# [Epoch 42/100] [Batch 0/2211] [D loss: 1.532003] [G loss: 0.846362]
# [Epoch 42/100] [Batch 1000/2211] [D loss: 1.601416] [G loss: 0.870830]
# [Epoch 42/100] [Batch 2000/2211] [D loss: 1.603661] [G loss: 0.873899]
# Saving models...
# [Epoch 43/100] [Batch 0/2211] [D loss: 1.591797] [G loss: 0.835321]
# [Epoch 43/100] [Batch 1000/2211] [D loss: 1.576203] [G loss: 0.889646]
# [Epoch 43/100] [Batch 2000/2211] [D loss: 1.574204] [G loss: 0.781686]
# Saving models...
# [Epoch 44/100] [Batch 0/2211] [D loss: 1.540699] [G loss: 0.836917]
# [Epoch 44/100] [Batch 1000/2211] [D loss: 1.616183] [G loss: 0.796247]
# [Epoch 44/100] [Batch 2000/2211] [D loss: 1.588976] [G loss: 0.850429]
# Saving models...
# [Epoch 45/100] [Batch 0/2211] [D loss: 1.589774] [G loss: 0.856395]
# [Epoch 45/100] [Batch 1000/2211] [D loss: 1.637640] [G loss: 0.836836]
# [Epoch 45/100] [Batch 2000/2211] [D loss: 1.649691] [G loss: 0.841665]
# Saving models...
# [Epoch 46/100] [Batch 0/2211] [D loss: 1.580330] [G loss: 0.827462]
# [Epoch 46/100] [Batch 1000/2211] [D loss: 1.604132] [G loss: 0.883763]
# [Epoch 46/100] [Batch 2000/2211] [D loss: 1.528347] [G loss: 0.846805]
# Saving models...
# [Epoch 47/100] [Batch 0/2211] [D loss: 1.648035] [G loss: 0.834103]
# [Epoch 47/100] [Batch 1000/2211] [D loss: 1.575801] [G loss: 0.801991]
# [Epoch 47/100] [Batch 2000/2211] [D loss: 1.531371] [G loss: 0.831818]
# Saving models...
# [Epoch 48/100] [Batch 0/2211] [D loss: 1.652612] [G loss: 0.859412]
# [Epoch 48/100] [Batch 1000/2211] [D loss: 1.533714] [G loss: 0.835823]
# [Epoch 48/100] [Batch 2000/2211] [D loss: 1.579742] [G loss: 0.803362]
# Saving models...
# [Epoch 49/100] [Batch 0/2211] [D loss: 1.565626] [G loss: 0.867992]
# [Epoch 49/100] [Batch 1000/2211] [D loss: 1.547583] [G loss: 0.848557]
# [Epoch 49/100] [Batch 2000/2211] [D loss: 1.591058] [G loss: 0.810046]
# Saving models...
# [Epoch 50/100] [Batch 0/2211] [D loss: 1.554952] [G loss: 0.842926]
# [Epoch 50/100] [Batch 1000/2211] [D loss: 1.538471] [G loss: 0.842769]
# [Epoch 50/100] [Batch 2000/2211] [D loss: 1.562928] [G loss: 0.891030]
# Saving models...
# [Epoch 51/100] [Batch 0/2211] [D loss: 1.539103] [G loss: 0.785191]
# [Epoch 51/100] [Batch 1000/2211] [D loss: 1.572464] [G loss: 0.851340]
# [Epoch 51/100] [Batch 2000/2211] [D loss: 1.600612] [G loss: 0.815934]
# Saving models...
# [Epoch 52/100] [Batch 0/2211] [D loss: 1.550502] [G loss: 0.851896]
# [Epoch 52/100] [Batch 1000/2211] [D loss: 1.527781] [G loss: 0.866915]
# [Epoch 52/100] [Batch 2000/2211] [D loss: 1.527828] [G loss: 0.881851]
# Saving models...
# [Epoch 53/100] [Batch 0/2211] [D loss: 1.603907] [G loss: 0.867147]
# [Epoch 53/100] [Batch 1000/2211] [D loss: 1.549428] [G loss: 0.932047]
# [Epoch 53/100] [Batch 2000/2211] [D loss: 1.601288] [G loss: 0.840545]
# Saving models...
# [Epoch 54/100] [Batch 0/2211] [D loss: 1.542043] [G loss: 0.825154]
# [Epoch 54/100] [Batch 1000/2211] [D loss: 1.572926] [G loss: 0.867578]
# [Epoch 54/100] [Batch 2000/2211] [D loss: 1.581063] [G loss: 0.847858]
# Saving models...
# [Epoch 55/100] [Batch 0/2211] [D loss: 1.537241] [G loss: 0.857247]
# [Epoch 55/100] [Batch 1000/2211] [D loss: 1.627867] [G loss: 0.845901]
# [Epoch 55/100] [Batch 2000/2211] [D loss: 1.652516] [G loss: 0.836592]
# Saving models...
# [Epoch 56/100] [Batch 0/2211] [D loss: 1.563962] [G loss: 0.891575]
# [Epoch 56/100] [Batch 1000/2211] [D loss: 1.582424] [G loss: 0.884489]
# [Epoch 56/100] [Batch 2000/2211] [D loss: 1.573059] [G loss: 0.841663]
# Saving models...
# [Epoch 57/100] [Batch 0/2211] [D loss: 1.560367] [G loss: 0.816736]
# [Epoch 57/100] [Batch 1000/2211] [D loss: 1.573483] [G loss: 0.834784]
# [Epoch 57/100] [Batch 2000/2211] [D loss: 1.570541] [G loss: 0.800772]
# Saving models...
# [Epoch 58/100] [Batch 0/2211] [D loss: 1.572124] [G loss: 0.855544]
# [Epoch 58/100] [Batch 1000/2211] [D loss: 1.611806] [G loss: 0.849893]
# [Epoch 58/100] [Batch 2000/2211] [D loss: 1.548978] [G loss: 0.832467]
# Saving models...
# [Epoch 59/100] [Batch 0/2211] [D loss: 1.622215] [G loss: 0.840792]
# [Epoch 59/100] [Batch 1000/2211] [D loss: 1.586594] [G loss: 0.793611]
# [Epoch 59/100] [Batch 2000/2211] [D loss: 1.652083] [G loss: 0.793427]
# Saving models...
# [Epoch 60/100] [Batch 0/2211] [D loss: 1.573123] [G loss: 0.780219]
# [Epoch 60/100] [Batch 1000/2211] [D loss: 1.568086] [G loss: 0.834325]
# [Epoch 60/100] [Batch 2000/2211] [D loss: 1.677812] [G loss: 0.798854]
# Saving models...
# [Epoch 61/100] [Batch 0/2211] [D loss: 1.599447] [G loss: 0.806929]
# [Epoch 61/100] [Batch 1000/2211] [D loss: 1.597446] [G loss: 0.808893]
# [Epoch 61/100] [Batch 2000/2211] [D loss: 1.658982] [G loss: 0.932825]
# Saving models...
# [Epoch 62/100] [Batch 0/2211] [D loss: 1.611208] [G loss: 0.876777]
# [Epoch 62/100] [Batch 1000/2211] [D loss: 1.554899] [G loss: 0.834927]
# [Epoch 62/100] [Batch 2000/2211] [D loss: 1.576626] [G loss: 0.847915]
# Saving models...
# [Epoch 63/100] [Batch 0/2211] [D loss: 1.578199] [G loss: 0.827128]
# [Epoch 63/100] [Batch 1000/2211] [D loss: 1.517710] [G loss: 0.845461]
# [Epoch 63/100] [Batch 2000/2211] [D loss: 1.581805] [G loss: 0.842236]
# Saving models...
# [Epoch 64/100] [Batch 0/2211] [D loss: 1.612252] [G loss: 0.845522]
# [Epoch 64/100] [Batch 1000/2211] [D loss: 1.590393] [G loss: 0.818344]
# [Epoch 64/100] [Batch 2000/2211] [D loss: 1.573370] [G loss: 0.834291]
# Saving models...
# [Epoch 65/100] [Batch 0/2211] [D loss: 1.569031] [G loss: 0.865175]
# [Epoch 65/100] [Batch 1000/2211] [D loss: 1.632507] [G loss: 0.802994]
# [Epoch 65/100] [Batch 2000/2211] [D loss: 1.664282] [G loss: 0.877988]
# Saving models...
# [Epoch 66/100] [Batch 0/2211] [D loss: 1.564744] [G loss: 0.844496]
# [Epoch 66/100] [Batch 1000/2211] [D loss: 1.561834] [G loss: 0.982744]
# [Epoch 66/100] [Batch 2000/2211] [D loss: 1.574004] [G loss: 0.842495]
# Saving models...
# [Epoch 67/100] [Batch 0/2211] [D loss: 1.559203] [G loss: 0.846642]
# [Epoch 67/100] [Batch 1000/2211] [D loss: 1.517524] [G loss: 0.843153]
# [Epoch 67/100] [Batch 2000/2211] [D loss: 1.583313] [G loss: 0.860045]
# Saving models...
# [Epoch 68/100] [Batch 0/2211] [D loss: 1.616634] [G loss: 0.841147]
# [Epoch 68/100] [Batch 1000/2211] [D loss: 1.624003] [G loss: 0.819398]
# [Epoch 68/100] [Batch 2000/2211] [D loss: 1.587440] [G loss: 0.824290]
# Saving models...
# [Epoch 69/100] [Batch 0/2211] [D loss: 1.623226] [G loss: 0.799901]
# [Epoch 69/100] [Batch 1000/2211] [D loss: 1.594925] [G loss: 0.853553]
# [Epoch 69/100] [Batch 2000/2211] [D loss: 1.527908] [G loss: 0.823231]
# Saving models...
# [Epoch 70/100] [Batch 0/2211] [D loss: 1.587935] [G loss: 0.874429]
# [Epoch 70/100] [Batch 1000/2211] [D loss: 1.533500] [G loss: 0.826690]
# [Epoch 70/100] [Batch 2000/2211] [D loss: 1.569886] [G loss: 0.869900]
# Saving models...
# [Epoch 71/100] [Batch 0/2211] [D loss: 1.570094] [G loss: 0.844181]
# [Epoch 71/100] [Batch 1000/2211] [D loss: 1.542001] [G loss: 0.765060]
# [Epoch 71/100] [Batch 2000/2211] [D loss: 1.559943] [G loss: 0.856350]
# Saving models...
# [Epoch 72/100] [Batch 0/2211] [D loss: 1.546180] [G loss: 0.855374]
# [Epoch 72/100] [Batch 1000/2211] [D loss: 1.600737] [G loss: 0.844331]
# [Epoch 72/100] [Batch 2000/2211] [D loss: 1.602194] [G loss: 0.844220]
# Saving models...
# [Epoch 73/100] [Batch 0/2211] [D loss: 1.565849] [G loss: 0.823768]
# [Epoch 73/100] [Batch 1000/2211] [D loss: 1.573129] [G loss: 0.841623]
# [Epoch 73/100] [Batch 2000/2211] [D loss: 1.521958] [G loss: 0.867591]
# Saving models...
# [Epoch 74/100] [Batch 0/2211] [D loss: 1.555639] [G loss: 0.856908]
# [Epoch 74/100] [Batch 1000/2211] [D loss: 1.542375] [G loss: 0.854130]
# [Epoch 74/100] [Batch 2000/2211] [D loss: 1.578075] [G loss: 0.859109]
# Saving models...
# [Epoch 75/100] [Batch 0/2211] [D loss: 1.613533] [G loss: 0.860270]
# [Epoch 75/100] [Batch 1000/2211] [D loss: 1.524001] [G loss: 0.851227]
# [Epoch 75/100] [Batch 2000/2211] [D loss: 1.596545] [G loss: 0.820242]
# Saving models...
# [Epoch 76/100] [Batch 0/2211] [D loss: 1.534559] [G loss: 0.858833]
# [Epoch 76/100] [Batch 1000/2211] [D loss: 1.601615] [G loss: 0.850960]
# [Epoch 76/100] [Batch 2000/2211] [D loss: 1.543060] [G loss: 0.853415]
# Saving models...
# [Epoch 77/100] [Batch 0/2211] [D loss: 1.574957] [G loss: 0.807538]
# [Epoch 77/100] [Batch 1000/2211] [D loss: 1.671224] [G loss: 0.920287]
# [Epoch 77/100] [Batch 2000/2211] [D loss: 1.567175] [G loss: 0.845101]
# Saving models...
# [Epoch 78/100] [Batch 0/2211] [D loss: 1.615021] [G loss: 0.819436]
# [Epoch 78/100] [Batch 1000/2211] [D loss: 1.605419] [G loss: 0.851988]
# [Epoch 78/100] [Batch 2000/2211] [D loss: 1.512700] [G loss: 0.849742]
# Saving models...
# [Epoch 79/100] [Batch 0/2211] [D loss: 1.576518] [G loss: 0.817458]
# [Epoch 79/100] [Batch 1000/2211] [D loss: 1.554054] [G loss: 0.844156]
# [Epoch 79/100] [Batch 2000/2211] [D loss: 1.554283] [G loss: 0.825058]
# Saving models...
# [Epoch 80/100] [Batch 0/2211] [D loss: 1.528841] [G loss: 0.836471]
# [Epoch 80/100] [Batch 1000/2211] [D loss: 1.610987] [G loss: 0.862195]
# [Epoch 80/100] [Batch 2000/2211] [D loss: 1.597076] [G loss: 0.801756]
# Saving models...
# [Epoch 81/100] [Batch 0/2211] [D loss: 1.576310] [G loss: 0.806444]
# [Epoch 81/100] [Batch 1000/2211] [D loss: 1.589803] [G loss: 0.936220]
# [Epoch 81/100] [Batch 2000/2211] [D loss: 1.655824] [G loss: 0.852431]
# Saving models...
# [Epoch 82/100] [Batch 0/2211] [D loss: 1.617168] [G loss: 0.879994]
# [Epoch 82/100] [Batch 1000/2211] [D loss: 1.590400] [G loss: 0.821787]
# [Epoch 82/100] [Batch 2000/2211] [D loss: 1.576366] [G loss: 0.830878]
# Saving models...
# [Epoch 83/100] [Batch 0/2211] [D loss: 1.572574] [G loss: 0.865304]
# [Epoch 83/100] [Batch 1000/2211] [D loss: 1.657569] [G loss: 0.840738]
# [Epoch 83/100] [Batch 2000/2211] [D loss: 1.648160] [G loss: 0.837086]
# Saving models...
# [Epoch 84/100] [Batch 0/2211] [D loss: 1.608940] [G loss: 0.840436]
# [Epoch 84/100] [Batch 1000/2211] [D loss: 1.598689] [G loss: 0.826417]
# [Epoch 84/100] [Batch 2000/2211] [D loss: 1.637573] [G loss: 0.823951]
# Saving models...
# [Epoch 85/100] [Batch 0/2211] [D loss: 1.602060] [G loss: 0.826623]
# [Epoch 85/100] [Batch 1000/2211] [D loss: 1.555465] [G loss: 0.824295]
# [Epoch 85/100] [Batch 2000/2211] [D loss: 1.587270] [G loss: 0.860599]
# Saving models...
# [Epoch 86/100] [Batch 0/2211] [D loss: 1.600361] [G loss: 0.828364]
# [Epoch 86/100] [Batch 1000/2211] [D loss: 1.572206] [G loss: 0.845708]
# [Epoch 86/100] [Batch 2000/2211] [D loss: 1.549787] [G loss: 0.851356]
# Saving models...
# [Epoch 87/100] [Batch 0/2211] [D loss: 1.559569] [G loss: 0.859304]
# [Epoch 87/100] [Batch 1000/2211] [D loss: 1.607710] [G loss: 0.822893]
# [Epoch 87/100] [Batch 2000/2211] [D loss: 1.570944] [G loss: 0.832274]
# Saving models...
# [Epoch 88/100] [Batch 0/2211] [D loss: 1.683775] [G loss: 0.825506]
# [Epoch 88/100] [Batch 1000/2211] [D loss: 1.541453] [G loss: 0.824952]
# [Epoch 88/100] [Batch 2000/2211] [D loss: 1.544589] [G loss: 0.828592]
# Saving models...
# [Epoch 89/100] [Batch 0/2211] [D loss: 1.557459] [G loss: 0.843028]
# [Epoch 89/100] [Batch 1000/2211] [D loss: 1.610819] [G loss: 0.810400]
# [Epoch 89/100] [Batch 2000/2211] [D loss: 1.548120] [G loss: 0.839071]
# Saving models...
# [Epoch 90/100] [Batch 0/2211] [D loss: 1.554292] [G loss: 0.849124]
# [Epoch 90/100] [Batch 1000/2211] [D loss: 1.549025] [G loss: 0.847187]
# [Epoch 90/100] [Batch 2000/2211] [D loss: 1.512530] [G loss: 0.837259]
# Saving models...
# [Epoch 91/100] [Batch 0/2211] [D loss: 1.585044] [G loss: 0.863938]
# [Epoch 91/100] [Batch 1000/2211] [D loss: 1.565829] [G loss: 0.840789]
# [Epoch 91/100] [Batch 2000/2211] [D loss: 1.571419] [G loss: 0.833977]
# Saving models...
# [Epoch 92/100] [Batch 0/2211] [D loss: 1.579003] [G loss: 0.852468]
# [Epoch 92/100] [Batch 1000/2211] [D loss: 1.544708] [G loss: 0.834707]
# [Epoch 92/100] [Batch 2000/2211] [D loss: 1.555902] [G loss: 0.848713]
# Saving models...
# [Epoch 93/100] [Batch 0/2211] [D loss: 1.601521] [G loss: 0.867057]
# [Epoch 93/100] [Batch 1000/2211] [D loss: 1.578180] [G loss: 0.846448]
# [Epoch 93/100] [Batch 2000/2211] [D loss: 1.631808] [G loss: 0.844507]
# Saving models...
# [Epoch 94/100] [Batch 0/2211] [D loss: 1.542863] [G loss: 0.821156]
# [Epoch 94/100] [Batch 1000/2211] [D loss: 1.520241] [G loss: 0.835654]
# [Epoch 94/100] [Batch 2000/2211] [D loss: 1.523412] [G loss: 0.849563]
# Saving models...
# [Epoch 95/100] [Batch 0/2211] [D loss: 1.573985] [G loss: 0.858944]
# [Epoch 95/100] [Batch 1000/2211] [D loss: 1.558794] [G loss: 0.817103]
# [Epoch 95/100] [Batch 2000/2211] [D loss: 1.585496] [G loss: 0.890565]
# Saving models...
# [Epoch 96/100] [Batch 0/2211] [D loss: 1.554919] [G loss: 0.840714]
# [Epoch 96/100] [Batch 1000/2211] [D loss: 1.577073] [G loss: 0.840914]
# [Epoch 96/100] [Batch 2000/2211] [D loss: 1.551930] [G loss: 0.852452]
# Saving models...
# [Epoch 97/100] [Batch 0/2211] [D loss: 1.568526] [G loss: 0.845504]
# [Epoch 97/100] [Batch 1000/2211] [D loss: 1.529866] [G loss: 0.834240]
# [Epoch 97/100] [Batch 2000/2211] [D loss: 1.532719] [G loss: 0.853685]
# Saving models...
# [Epoch 98/100] [Batch 0/2211] [D loss: 1.573599] [G loss: 0.843786]
# [Epoch 98/100] [Batch 1000/2211] [D loss: 1.563299] [G loss: 0.845417]
# [Epoch 98/100] [Batch 2000/2211] [D loss: 1.564786] [G loss: 0.829065]
# Saving models...
# [Epoch 99/100] [Batch 0/2211] [D loss: 1.579490] [G loss: 0.832781]
# [Epoch 99/100] [Batch 1000/2211] [D loss: 1.551246] [G loss: 0.838717]
# [Epoch 99/100] [Batch 2000/2211] [D loss: 1.537662] [G loss: 0.857890]
# Saving models...
